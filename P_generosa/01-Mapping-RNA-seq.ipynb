# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2-build \
/Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k.fa \
/Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k-bowtie-index
# Out:
# Settings:
#   Output files: "/Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k-bowtie-index.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   /Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k.fa
# Building a SMALL index
# Reading reference sizes
#   Time reading reference sizes: 00:00:03
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:02
# ...

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2
# Out:
# No index, query, or output file specified!
# Bowtie 2 version 2.2.4 by Ben Langmead (langmea@cs.jhu.edu, www.cs.jhu.edu/~langmea)
# Usage:
#   bowtie2 [options]* -x <bt2-idx> {-1 <m1> -2 <m2> | -U <r>} [-S <sam>]
#
#   <bt2-idx>  Index filename prefix (minus trailing .X.bt2).
#              NOTE: Bowtie 1 and Bowtie 2 indexes are not compatible.
#   <m1>       Files with #1 mates, paired with files in <m2>.
#              Could be gzip'ed (extension: .gz) or bzip2'ed (extension: .bz2).
#   <m2>       Files with #2 mates, paired with files in <m1>.
#              Could be gzip'ed (extension: .gz) or bzip2'ed (extension: .bz2).
#   <r>        Files with unpaired reads.
#              Could be gzip'ed (extension: .gz) or bzip2'ed (extension: .bz2).
#   <sam>      File for SAM output (default: stdout)
#
#   <m1>, <m2>, <r> can be comma-separated lists (no whitespace) and can be
#   specified many times.  E.g. '-U file1.fq,file2.fq -U file3.fq'.
#
# Options (defaults in parentheses):
#
# ...

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k-bowtie-index \
-1 /Volumes/web/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_F_GGCTAC_L006_R1_001_val_2.fq \
-2 /Volumes/web/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_F_GGCTAC_L006_R2_001_val_1.fq \
-p 4 \
-S /Volumes/web-1/halfshell/working-directory/16-12-16/bw-Geo_Pool_F_GGCTAC.sam
# Out:
# Error: Read HWI-D00743:26:C7C84ACXX:6:1109:6517:91454 2:N:0:GGCTAC has more read characters than quality values.
# libc++abi.dylib: terminating with uncaught exception of type int
# (ERR): bowtie2-align died with signal 6 (ABRT)

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k-bowtie-index \
-1 /Volumes/web-1/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_M_CTTGTA_L006_R1_001_val_2.fq \
-2 /Volumes/web-1/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_M_CTTGTA_L006_R2_001_val_1.fq \
-p 6 \
-S /Volumes/web-1/halfshell/working-directory/16-12-16/bw-Geo_Pool_M_CTTGTA.sam
# Out:
# 116711310 reads; of these:
#   116711310 (100.00%) were paired; of these:
#     110819539 (94.95%) aligned concordantly 0 times
#     5433477 (4.66%) aligned concordantly exactly 1 time
#     458294 (0.39%) aligned concordantly >1 times
#     ----
#     110819539 pairs aligned concordantly 0 times; of these:
#       543389 (0.49%) aligned discordantly 1 time
#     ----
#     110276150 pairs aligned 0 times concordantly or discordantly; of these:
#       220552300 mates make up the pairs; of these:
#         214491636 (97.25%) aligned 0 times
#         5608759 (2.54%) aligned exactly 1 time
#         451905 (0.20%) aligned >1 times
# 8.11% overall alignment rate

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k-bowtie-index \
-1 /Volumes/web-1/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_F_GGCTAC_L006_R1_001_val_2.fq \
-2 /Volumes/web-1/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_F_GGCTAC_L006_R2_001_val_1.fq \
-p 4 \
-S /Volumes/caviar/wd/2016-12-16/bw-Geo_Pool_F_GGCTAC.sam
# Out:
# 103213920 reads; of these:
#   103213920 (100.00%) were paired; of these:
#     87685353 (84.95%) aligned concordantly 0 times
#     14042158 (13.60%) aligned concordantly exactly 1 time
#     1486409 (1.44%) aligned concordantly >1 times
#     ----
#     87685353 pairs aligned concordantly 0 times; of these:
#       1285042 (1.47%) aligned discordantly 1 time
#     ----
#     86400311 pairs aligned 0 times concordantly or discordantly; of these:
#       172800622 mates make up the pairs; of these:
#         164109929 (94.97%) aligned 0 times
#         7580613 (4.39%) aligned exactly 1 time
#         1110080 (0.64%) aligned >1 times
# 20.50% overall alignment rate

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k-bowtie-index \
-1 /Volumes/web-1/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_M_CTTGTA_L006_R1_001_val_2.fq \
-2 /Volumes/web-1/halfshell/bu-data-genomic/tentacle/Geoduck_v3/Geo_Pool_M_CTTGTA_L006_R2_001_val_1.fq \
-p 6 \
-S /Volumes/caviar/wd/2016-12-16/bw-Geo_Pool_M_CTTGTA.sam
# Out:
# 116711310 reads; of these:
#   116711310 (100.00%) were paired; of these:
#     110819539 (94.95%) aligned concordantly 0 times
#     5433477 (4.66%) aligned concordantly exactly 1 time
#     458294 (0.39%) aligned concordantly >1 times
#     ----
#     110819539 pairs aligned concordantly 0 times; of these:
#       543389 (0.49%) aligned discordantly 1 time
#     ----
#     110276150 pairs aligned 0 times concordantly or discordantly; of these:
#       220552300 mates make up the pairs; of these:
#         214491636 (97.25%) aligned 0 times
#         5608759 (2.54%) aligned exactly 1 time
#         451905 (0.20%) aligned >1 times
# 8.11% overall alignment rate

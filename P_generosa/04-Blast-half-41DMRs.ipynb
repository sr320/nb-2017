# %% [markdown]
# # Blasting regions around DMRs.

# %%
# !head -2 /Users/sr320/data-genomic/wd/2017-02-07/41DMR.fa
# Out:
# >scaffold103946-20422
# ...

# %%
# !fgrep -c ">" /Users/sr320/data-genomic/wd/2017-02-07/41DMR.fa
# Out:
# 18

# %%
# !blast
# Out:
# /bin/sh: blast: command not found

# %%
# !/Applications/bioinfo/ncbi-blast-2.5.0\+/bin/blastx \
-query /Users/sr320/data-genomic/wd/2017-02-07/41DMR.fa \
-db /Users/sr320/data-genomic/blast/db/uniprot_sprot_2016_09 \
-out /Users/sr320/data-genomic/wd/2017-02-07/18dmr-blastx-uniprot.tab \
-outfmt 6 \
-num_threads 8

# %%
# !head /Users/sr320/data-genomic/wd/2017-02-07/18dmr-blastx-uniprot.tab
# Out:
# scaffold103946-20422	sp|P04323|POL3_DROME	42.623	122	62	3	696	337	520	635	1.47e-19	90.5
# scaffold103946-20422	sp|P10394|POL4_DROME	41.818	110	58	2	696	379	627	734	6.35e-18	85.9
# scaffold103946-20422	sp|P20825|POL2_DROME	39.815	108	59	2	696	379	519	622	1.80e-16	81.6
# scaffold103946-20422	sp|Q8I7P9|POL5_DROME	40.541	111	59	3	696	379	446	554	1.52e-14	75.9
# scaffold103946-20422	sp|Q7LHG5|YI31B_YEAST	28.319	226	128	8	663	28	942	1147	1.47e-13	73.2
# scaffold103946-20422	sp|Q99315|YG31B_YEAST	27.984	243	135	9	696	28	899	1121	1.65e-13	72.8
# scaffold103946-20422	sp|P10401|POLY_DROME	32.192	146	92	5	696	271	506	648	6.61e-12	68.2
# scaffold103946-20422	sp|P0CT40|TF29_SCHPO	28.148	135	89	3	696	313	719	852	1.78e-08	58.2
# scaffold103946-20422	sp|P0CT39|TF26_SCHPO	28.148	135	89	3	696	313	719	852	1.78e-08	58.2
# scaffold103946-20422	sp|P0CT38|TF25_SCHPO	28.148	135	89	3	696	313	719	852	1.78e-08	58.2

# %%
# !/Applications/bioinfo/ncbi-blast-2.5.0\+/bin/blastn \
-query /Users/sr320/data-genomic/wd/2017-02-07/41DMR.fa \
-db /Volumes/Histidine/CLC_blastdatabases/nt \
-out /Users/sr320/data-genomic/wd/2017-02-07/18dmr-blastn-nt.tab \
-num_threads 8

# %% [markdown]
# Via NCBI
# ```
# BLASTN 2.6.1+
# Reference: Stephen F. Altschul, Thomas L. Madden, Alejandro
# A. Schaffer, Jinghui Zhang, Zheng Zhang, Webb Miller, and
# David J. Lipman (1997), "Gapped BLAST and PSI-BLAST: a new
# generation of protein database search programs", Nucleic
# Acids Res. 25:3389-3402.
#
#
# RID: 9M00UZ0M015
#
#
# Database: Nucleotide collection (nt)
#            41,252,795 sequences; 137,855,211,127 total letters
# Query= scaffold103946-20422
#
# Length=698
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# CT956089.5  Zebrafish DNA sequence from clone CH73-377N7 in li...  69.8    9e-08
# BX548047.12  Zebrafish DNA sequence from clone CH211-77G15 in ...  69.8    9e-08
# CR376750.10  Zebrafish DNA sequence from clone DKEY-92I15 in l...  69.8    9e-08
# AL935048.7  Zebrafish DNA sequence from clone CH211-168M7 in l...  69.8    9e-08
# XM_011435015.1  PREDICTED: Crassostrea gigas uncharacterized p...  64.4    4e-06
# CU013528.12  Zebrafish DNA sequence from clone DKEY-240G9, com...  64.4    4e-06
# CT955996.8  Zebrafish DNA sequence from clone CH211-67B18 in l...  59.0    2e-04
# GU129140.1  Salmo salar IgH locus B genomic sequence               57.2    5e-04
# EU816603.1  Salmo salar clone BAC S0142M23, complete sequence      57.2    5e-04
# XM_020072616.1  PREDICTED: Crassostrea gigas uncharacterized p...  50.0    0.081
# XM_011418264.1  PREDICTED: Crassostrea gigas uncharacterized p...  50.0    0.081
# AC144644.3  Medicago truncatula clone mth2-14l3, complete sequ...  48.2    0.28
# XM_018096709.1  PREDICTED: Xenopus tropicalis tip elongation a...  46.4    0.99
# XM_018096708.1  PREDICTED: Xenopus tropicalis tip elongation a...  46.4    0.99
# XM_002938864.4  PREDICTED: Xenopus tropicalis tip elongation a...  46.4    0.99
# CP007080.1  Drosophila melanogaster Unmapped_Scaffold_4_D1555_...  46.4    0.99
# AE014297.3  Drosophila melanogaster chromosome 3R                  46.4    0.99
# AC246288.1  Drosophila melanogaster clone BACR19D10, complete ...  46.4    0.99
# CP000204.1  Drosophila melanogaster genomic scaffold 211000022...  46.4    0.99
# CP000184.1  Drosophila melanogaster genomic scaffold 211000022...  46.4    0.99
# XM_019041035.1  PREDICTED: Bemisia tabaci frizzled-4-like (LOC...  44.6    3.5
# XR_001686146.1  PREDICTED: Gossypium hirsutum uncharacterized ...  44.6    3.5
# XM_015663983.1  PREDICTED: Neodiprion lecontei formin-binding ...  44.6    3.5
# CP011886.1  Ovis canadensis canadensis isolate 43U chromosome ...  44.6    3.5
# CP011901.1  Ovis canadensis canadensis isolate 43U chromosome ...  44.6    3.5
# XR_001124895.1  PREDICTED: Gossypium raimondii uncharacterized...  44.6    3.5
# XR_001124894.1  PREDICTED: Gossypium raimondii uncharacterized...  44.6    3.5
# LL879749.1  Schistosoma margrebowiei genome assembly S_margreb...  44.6    3.5
# KF319019.1  Mya arenaria retrotransposon steamer GagPol gene, ...  44.6    3.5
# HG975519.1  Solanum lycopersicum chromosome ch07, complete genome  44.6    3.5
# XM_008483658.1  PREDICTED: Diaphorina citri uncharacterized pr...  44.6    3.5
# AC235450.1  Glycine max strain Williams 82 clone GM_WBb0164I03...  44.6    3.5
# AC235449.1  Glycine max strain Williams 82 clone GM_WBb0162K15...  44.6    3.5
# AC235398.1  Glycine max strain Williams 82 clone GM_WBb0119F07...  44.6    3.5
# AC235395.1  Glycine max strain Williams 82 clone GM_WBb0118D03...  44.6    3.5
# AC235309.1  Glycine max strain Williams 82 clone GM_WBb0069M12...  44.6    3.5
# AC235266.1  Glycine max strain Williams 82 clone GM_WBb0042L13...  44.6    3.5
# AC235207.1  Glycine max strain Williams 82 clone GM_WBb0018M13...  44.6    3.5
# Query= scaffold106982-14135
#
# Length=344
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# CP001816.1  Sulfurospirillum deleyianum DSM 6946, complete genome  51.8    0.023
# XM_015317522.1  PREDICTED: Polistes dominula spliceosome-assoc...  50.0    0.081
# LT594095.1  Acinetobacter baumannii strain 3027STDY5784958 gen...  48.2    0.28
# XM_008208804.2  PREDICTED: Nasonia vitripennis serine/threonin...  48.2    0.28
# KT359617.1  Acinetobacter baumannii strain BAL_114 KL58 capsul...  48.2    0.28
# CP012524.1  Drosophila busckii chromosome 2R sequence              48.2    0.28
# HG975447.1  Solanum pennellii chromosome ch08, complete genome     46.4    0.99
# CP017834.1  Proteobacteria bacterium Nonnen-W8red strain MWH-N...  44.6    3.5
# CP015750.1  Pectobacterium wasabiae CFBP 3304, complete genome     44.6    3.5
# XM_016518619.1  PREDICTED: Sinocyclocheilus rhinocerous cytopl...  44.6    3.5
# XM_014431124.1  PREDICTED: Halyomorpha halys PDZ and LIM domai...  44.6    3.5
# XM_014431123.1  PREDICTED: Halyomorpha halys PDZ and LIM domai...  44.6    3.5
# LM383915.1  Hymenolepis diminuta genome assembly H_diminuta_De...  44.6    3.5
# LL757251.1  Gongylonema pulchrum genome assembly G_pulchrum_Ho...  44.6    3.5
# LK927993.1  Caenorhabditis elegans genome assembly C_elegans_B...  44.6    3.5
# LN609396.1  Strongyloides ratti genome assembly S_ratti_ED321,...  44.6    3.5
# HG975448.1  Solanum pennellii chromosome ch09, complete genome     44.6    3.5
# XM_006820957.1  PREDICTED: Saccoglossus kowalevskii uncharacte...  44.6    3.5
# FJ968741.1  Parachlorella kessleri culture-collection SAG:211-...  44.6    3.5
# AC225494.7  Medicago truncatula clone mth2-46h18, complete seq...  44.6    3.5
# AC166141.2  Xenopus tropicalis clone CH216-52F23, complete seq...  44.6    3.5
# FO081477.1  Caenorhabditis elegans Cosmid F55F8, complete sequ...  44.6    3.5
# AC156244.2  Xenopus tropicalis clone CH216-92I18, complete seq...  44.6    3.5
# Query= scaffold107590-8577
#
# Length=714
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# KM589149.1  Corbicula fluminea microsatellite Cf140 sequence       86.0    1e-12
# XM_011447348.2  PREDICTED: Crassostrea gigas zinc finger and B...  80.6    5e-11
# XM_011447347.2  PREDICTED: Crassostrea gigas zinc finger and B...  80.6    5e-11
# XM_011447345.2  PREDICTED: Crassostrea gigas zinc finger and B...  80.6    5e-11
# XM_011447344.2  PREDICTED: Crassostrea gigas zinc finger and B...  80.6    5e-11
# XM_011447343.2  PREDICTED: Crassostrea gigas zinc finger and B...  80.6    5e-11
# XR_002198807.1  PREDICTED: Crassostrea gigas uncharacterized L...  78.8    2e-10
# FJ607752.1  Pinctada maxima microsatellite HUPMax06 sequence       77.0    6e-10
# GU207462.1  Crassostrea gigas clone CG_Ba80D21, complete sequence  77.0    6e-10
# GU207458.1  Crassostrea gigas clone CG_Ba118P9, complete sequence  77.0    6e-10
# GU207445.1  Crassostrea gigas clone CG_Ba172M23, complete sequ...  77.0    6e-10
# GU207426.1  Crassostrea gigas clone CG_Ba17L12, complete sequence  77.0    6e-10
# XM_011456631.2  PREDICTED: Crassostrea gigas uncharacterized L...  71.6    2e-08
# GU207411.1  Crassostrea gigas clone CG_Ba18I16, complete sequence  71.6    2e-08
# KP257288.1  Meretrix meretrix long-chain fatty acid CoA ligase...  69.8    9e-08
# GU207438.1  Crassostrea gigas clone CG_Ba89P3, complete sequence   66.2    1e-06
# GU207437.1  Crassostrea gigas clone CG_Ba108I1, complete sequence  66.2    1e-06
# GU207435.1  Crassostrea gigas clone CG_Ba18M12, complete sequence  66.2    1e-06
# GU207432.1  Crassostrea gigas clone CG_Ba173F2, complete sequence  66.2    1e-06
# GU207431.1  Crassostrea gigas clone CG_Ba59K18, complete sequence  66.2    1e-06
# GU207430.1  Crassostrea gigas clone CG_Ba133A21, complete sequ...  66.2    1e-06
# GU207427.1  Crassostrea gigas clone CG_Ba34I8, complete sequence   66.2    1e-06
# GU207456.1  Crassostrea gigas clone CG_Ba188K9, complete sequence  64.4    4e-06
# HQ593147.1  Argopecten irradians clone AICL115 microsatellite ...  62.6    1e-05
# KR704607.1  Mercenaria mercenaria microsatellite G6 sequence       60.8    4e-05
# JX391920.1  Portunus trituberculatus clone XCA-41 microsatelli...  60.8    4e-05
# JQ768809.1  Portunus trituberculatus clone GA-18 microsatellit...  60.8    4e-05
# XM_011416913.2  PREDICTED: Crassostrea gigas fructosamine-3-ki...  59.0    2e-04
# XM_011447547.2  PREDICTED: Crassostrea gigas metallo-beta-lact...  59.0    2e-04
# KF469260.1  Bullacta exarata microsatellite Bex16-224 sequence     59.0    2e-04
# EU446454.1  Spisula solidissima clone S3-B9_RUSS47 microsatell...  59.0    2e-04
# KC981676.1  Donax trunculus clone DTC12Alu microsatellite sequ...  57.2    5e-04
# XM_011452059.2  PREDICTED: Crassostrea gigas uncharacterized L...  53.6    0.007
# XM_014191967.1  PREDICTED: Salmo salar zinc finger and BTB dom...  50.0    0.081
# XM_014191966.1  PREDICTED: Salmo salar zinc finger and BTB dom...  50.0    0.081
# XM_013238398.1  PREDICTED: Biomphalaria glabrata carbamoyl-pho...  50.0    0.081
# KC981717.1  Donax trunculus clone 84mob18 MITE DTC84, complete...  50.0    0.081
# XM_017911085.1  PREDICTED: Eufriesea mexicana DNA ligase 1 (LO...  48.2    0.28
# XM_017055787.1  PREDICTED: Apis cerana DNA ligase 1 (LOC107997...  48.2    0.28
# XM_017055786.1  PREDICTED: Apis cerana DNA ligase 1 (LOC107997...  48.2    0.28
# XM_017055785.1  PREDICTED: Apis cerana DNA ligase 1 (LOC107997...  48.2    0.28
# XM_006560953.2  PREDICTED: Apis mellifera DNA ligase 1 (LOC408...  48.2    0.28
# XM_006560952.2  PREDICTED: Apis mellifera DNA ligase 1 (LOC408...  48.2    0.28
# XM_006560951.2  PREDICTED: Apis mellifera DNA ligase 1 (LOC408...  48.2    0.28
# XM_003698547.2  PREDICTED: Apis florea DNA ligase 1 (LOC100870...  48.2    0.28
# XM_011179391.1  PREDICTED: Bactrocera cucurbitae muscle segmen...  48.2    0.28
# XM_006609684.1  PREDICTED: Apis dorsata DNA ligase 1-like (LOC...  48.2    0.28
# XM_006609683.1  PREDICTED: Apis dorsata DNA ligase 1-like (LOC...  48.2    0.28
# XM_006609682.1  PREDICTED: Apis dorsata DNA ligase 1-like (LOC...  48.2    0.28
# GQ121385.1  Mercenaria mercenaria microsatellite RUMM021 sequence  48.2    0.28
# Query= scaffold112102-14447
#
# Length=1474
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# XM_011453356.2  PREDICTED: Crassostrea gigas Krueppel-like fac...  150     3e-32
# XM_009063051.1  Lottia gigantea hypothetical protein partial mRNA  86.0    1e-12
# XM_005099113.2  PREDICTED: Aplysia californica zinc finger pro...  75.2    2e-09
# XM_013229633.1  PREDICTED: Biomphalaria glabrata Krueppel-like...  66.2    1e-06
# XM_013550744.1  PREDICTED: Lingula anatina Krueppel-like facto...  64.4    4e-06
# XM_014914584.1  PREDICTED: Octopus bimaculoides Krueppel-like ...  62.6    1e-05
# XM_018715993.1  PREDICTED: Anoplophora glabripennis Krueppel-l...  59.0    2e-04
# XM_009063052.1  Lottia gigantea hypothetical protein partial mRNA  59.0    2e-04
# XM_015929299.1  PREDICTED: Tetranychus urticae Krueppel-like f...  55.4    0.002
# XM_018567237.1  PREDICTED: Nanorana parkeri Kruppel like facto...  53.6    0.007
# XM_015244454.1  PREDICTED: Vicugna pacos Kruppel-like factor 1...  53.6    0.007
# XM_008555688.2  PREDICTED: Microplitis demolitor Krueppel-like...  53.6    0.007
# XM_004520569.2  PREDICTED: Ceratitis capitata transcription fa...  53.6    0.007
# XM_019529802.1  PREDICTED: Crocodylus porosus Kruppel like fac...  51.8    0.023
# XM_019529801.1  PREDICTED: Crocodylus porosus Kruppel like fac...  51.8    0.023
# XM_019529800.1  PREDICTED: Crocodylus porosus Kruppel like fac...  51.8    0.023
# XM_019529799.1  PREDICTED: Crocodylus porosus Kruppel like fac...  51.8    0.023
# XM_019524879.1  PREDICTED: Gavialis gangeticus Kruppel like fa...  51.8    0.023
# XM_019524878.1  PREDICTED: Gavialis gangeticus Kruppel like fa...  51.8    0.023
# XM_019524877.1  PREDICTED: Gavialis gangeticus Kruppel like fa...  51.8    0.023
# XM_019524876.1  PREDICTED: Gavialis gangeticus Kruppel like fa...  51.8    0.023
# XM_019524875.1  PREDICTED: Gavialis gangeticus Kruppel like fa...  51.8    0.023
# XM_019524874.1  PREDICTED: Gavialis gangeticus Kruppel like fa...  51.8    0.023
# XM_019488580.1  PREDICTED: Alligator mississippiensis Kruppel ...  51.8    0.023
# XM_019488579.1  PREDICTED: Alligator mississippiensis Kruppel ...  51.8    0.023
# XM_019488578.1  PREDICTED: Alligator mississippiensis Kruppel ...  51.8    0.023
# XM_019488577.1  PREDICTED: Alligator mississippiensis Kruppel ...  51.8    0.023
# XM_019488576.1  PREDICTED: Alligator mississippiensis Kruppel ...  51.8    0.023
# XM_014610470.2  PREDICTED: Alligator mississippiensis Kruppel ...  51.8    0.023
# XM_019488575.1  PREDICTED: Alligator mississippiensis Kruppel ...  51.8    0.023
# XM_017163722.1  PREDICTED: Drosophila kikkawai WD repeat domai...  51.8    0.023
# XM_015271740.1  PREDICTED: Diachasma alloeum Krueppel-like fac...  51.8    0.023
# XM_015271739.1  PREDICTED: Diachasma alloeum Krueppel-like fac...  51.8    0.023
# XM_006018139.2  PREDICTED: Alligator sinensis Kruppel-like fac...  51.8    0.023
# XM_014517167.1  PREDICTED: Alligator sinensis Kruppel-like fac...  51.8    0.023
# XM_006018138.2  PREDICTED: Alligator sinensis Kruppel-like fac...  51.8    0.023
# XM_006018137.2  PREDICTED: Alligator sinensis Kruppel-like fac...  51.8    0.023
# XM_014517166.1  PREDICTED: Alligator sinensis Kruppel-like fac...  51.8    0.023
# XM_006018136.2  PREDICTED: Alligator sinensis Kruppel-like fac...  51.8    0.023
# XM_013926253.1  PREDICTED: Limulus polyphemus Krueppel-like fa...  51.8    0.023
# XM_004206754.2  PREDICTED: Hydra vulgaris zinc finger protein ...  51.8    0.023
# LN713263.1  Cucumis melo genomic chromosome, chr_9                 51.8    0.023
# LN681893.1  Cucumis melo genomic scaffold, anchoredscaffold00055   51.8    0.023
# XM_004371422.1  PREDICTED: Trichechus manatus latirostris Krup...  51.8    0.023
# XM_001660600.1  Aedes aegypti AAEL010126-RA partial mRNA           51.8    0.023
# XM_019921168.1  PREDICTED: Tursiops truncatus Kruppel like fac...  50.0    0.081
# XM_019738166.1  PREDICTED: Rhinolophus sinicus Kruppel like fa...  50.0    0.081
# XM_019738165.1  PREDICTED: Rhinolophus sinicus Kruppel like fa...  50.0    0.081
# XM_019738164.1  PREDICTED: Rhinolophus sinicus Kruppel like fa...  50.0    0.081
# XM_019738163.1  PREDICTED: Rhinolophus sinicus Kruppel like fa...  50.0    0.081
# Query= scaffold11815-14456
#
# Length=992
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# KJ460357.1  Panopea globosa microsatellite PglobT65 sequence       107     3e-19
# XM_020073419.1  PREDICTED: Crassostrea gigas protein PRRC2C (L...  73.4    7e-09
# LM167685.1  Schistosoma mattheei genome assembly S_mattheei_De...  51.8    0.023
# LM082286.1  Schistosoma curassoni genome assembly S_curassoni_...  51.8    0.023
# LM001093.1  Wuchereria bancrofti genome assembly W_bancrofti_J...  51.8    0.023
# LT594789.1  Theobroma cacao genome assembly, chromosome: II        50.0    0.081
# XM_005252694.3  PREDICTED: Homo sapiens family with sequence s...  50.0    0.081
# XM_017016542.1  PREDICTED: Homo sapiens family with sequence s...  50.0    0.081
# XM_017016541.1  PREDICTED: Homo sapiens family with sequence s...  50.0    0.081
# XM_017016540.1  PREDICTED: Homo sapiens family with sequence s...  50.0    0.081
# XM_017016539.1  PREDICTED: Homo sapiens family with sequence s...  50.0    0.081
# XM_017016538.1  PREDICTED: Homo sapiens family with sequence s...  50.0    0.081
# XM_017016537.1  PREDICTED: Homo sapiens family with sequence s...  50.0    0.081
# NG_033919.2  Homo sapiens dedicator of cytokinesis 1 (DOCK1), ...  50.0    0.081
# HG975443.1  Solanum pennellii chromosome ch04, complete genome     50.0    0.081
# BX901944.17  Zebrafish DNA sequence from clone DKEY-61C16 in l...  50.0    0.081
# HQ872008.1  Fergusonina sp. LAN-2011 mitochondrion, complete g...  50.0    0.081
# NM_001039762.2  Homo sapiens family with sequence similarity 1...  50.0    0.081
# AF488415.1  Triticum monococcum chromosome 7Am BAC 5K14 comple...  50.0    0.081
# AK127465.1  Homo sapiens cDNA FLJ45557 fis, clone BRTHA3002411     50.0    0.081
# AL390920.22  Human DNA sequence from clone RP11-384P18 on chro...  50.0    0.081
# LT669791.1  Arabis alpina genome assembly, chromosome: chr4        48.2    0.28
# XM_007575277.2  PREDICTED: Poecilia formosa uncharacterized LO...  48.2    0.28
# XR_001474946.1  PREDICTED: Solanum tuberosum uncharacterized L...  48.2    0.28
# AP015042.1  Vigna angularis var. angularis DNA, chromosome 9, ...  48.2    0.28
# XM_014990027.1  PREDICTED: Poecilia mexicana uncharacterized L...  48.2    0.28
# XM_015035769.1  PREDICTED: Poecilia latipinna uncharacterized ...  48.2    0.28
# XM_013546828.1  PREDICTED: Lingula anatina protein PRRC2C-like...  48.2    0.28
# XM_013546827.1  PREDICTED: Lingula anatina protein PRRC2C-like...  48.2    0.28
# XM_013546826.1  PREDICTED: Lingula anatina protein PRRC2C-like...  48.2    0.28
# CP011893.1  Ovis canadensis canadensis isolate 43U chromosome ...  48.2    0.28
# XM_011694827.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011694826.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011694825.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011694824.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011694823.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011694822.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011694821.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011694820.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# KJ460346.1  Panopea globosa microsatellite PglobT41 sequence       48.2    0.28
# LM423460.1  Enterobius vermicularis genome assembly E_vermicul...  48.2    0.28
# LM248978.1  Strongylus vulgaris genome assembly S_vulgaris_Ken...  48.2    0.28
# LM149841.1  Schistosoma mattheei genome assembly S_mattheei_De...  48.2    0.28
# LL999049.1  Strongyloides stercoralis genome assembly S_sterco...  48.2    0.28
# LM523185.1  Parastrongyloides trichosuri genome assembly P_tri...  48.2    0.28
# LN590708.1  Cyprinus carpio genome assembly common carp genome...  48.2    0.28
# HG975520.1  Solanum lycopersicum chromosome ch08, complete genome  48.2    0.28
# HG975513.1  Solanum lycopersicum chromosome ch01, complete genome  48.2    0.28
# CP003806.1  Candidatus Kinetoplastibacterium galatii TCC219, c...  48.2    0.28
# AC242638.3  Rattus norvegicus Y Chr BAC RNECO-125D01 (Amplicon...  48.2    0.28
# Query= scaffold11917-28699
#
# Length=1218
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# EU054099.1  Spisula solidissima cnRNA183, complete sequence        77.0    6e-10
# KF649195.1  Paphia amabilis microsatellite Pam18 sequence          53.6    0.007
# HF933216.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  46.4    0.99
# LM530264.1  Mesocestoides corti genome assembly M_corti_Specht...  46.4    0.99
# XM_020070441.1  PREDICTED: Crassostrea gigas uncharacterized L...  44.6    3.5
# XM_019311535.1  PREDICTED: Ipomoea nil probable methyltransfer...  44.6    3.5
# XM_019311534.1  PREDICTED: Ipomoea nil probable methyltransfer...  44.6    3.5
# LK964394.1  Brugia pahangi genome assembly B_pahangi_Glasgow, ...  44.6    3.5
# LM682525.1  Protopolystoma xenopodis genome assembly P_xenopod...  44.6    3.5
# LN590675.1  Cyprinus carpio genome assembly common carp genome...  44.6    3.5
# LL713236.1  Elaeophora elaphi genome assembly E_elaphi, scaffo...  44.6    3.5
# HG975519.1  Solanum lycopersicum chromosome ch07, complete genome  44.6    3.5
# HG975446.1  Solanum pennellii chromosome ch07, complete genome     44.6    3.5
# HG975443.1  Solanum pennellii chromosome ch04, complete genome     44.6    3.5
# XM_006683048.1  Batrachochytrium dendrobatidis JAM81 hypotheti...  44.6    3.5
# JQ876861.1  Crocodylus porosus isolate 8048cro ultra conserved...  44.6    3.5
# XM_001583080.1  Trichomonas vaginalis G3 hypothetical protein ...  44.6    3.5
# AM434196.2  Vitis vinifera contig VV78X087196.5, whole genome ...  44.6    3.5
# CP000685.1  Flavobacterium johnsoniae UW101, complete genome       44.6    3.5
# Query= scaffold1242-12404
#
# Length=882
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# KM596505.1  Pinctada fucata galectin gene, promoter region         66.2    1e-06
# KX355771.1  Panopea globosa microsatellite Pglo4_5 sequence        64.4    4e-06
# KF017177.1  Pinctada maxima microsatellite D2-E11 sequence         64.4    4e-06
# FJ607770.1  Pinctada maxima microsatellite HUPMax24 sequence       64.4    4e-06
# JQ328043.1  Pinctada martensi clone PmartE02 microsatellite se...  62.6    1e-05
# GQ129702.1  Gibbula cineraria clone Gcin23 microsatellite sequ...  59.0    2e-04
# AP009180.1  Candidatus Carsonella ruddii PV DNA, complete genome   59.0    2e-04
# KT037729.1  Mizuhopecten yessoensis isolate PYMIG Rho GTPase g...  57.2    5e-04
# JN703459.1  Chlamys farreri clone BAC Bam040H03, complete sequ...  57.2    5e-04
# EU122193.1  Myxine glutinosa clone BAC 90C8, complete sequence     57.2    5e-04
# KU682331.1  Donax trunculus clone BIV31a satellite BIV160 sequ...  55.4    0.002
# LM398150.1  Hymenolepis nana genome assembly H_nana_Japan, sca...  55.4    0.002
# HG975520.1  Solanum lycopersicum chromosome ch08, complete genome  55.4    0.002
# KC981745.1  Donax trunculus clone BIV31 satellite DtBIV160 seq...  55.4    0.002
# CP003280.1  Aequorivita sublithincola DSM 14238, complete genome   55.4    0.002
# AP009263.1  Solanum lycopersicum genomic DNA, chromosome 8, cl...  55.4    0.002
# LT594791.1  Theobroma cacao genome assembly, chromosome: IV        53.6    0.007
# XM_001031720.3  Tetrahymena thermophila SB210 secreted protein...  53.6    0.007
# LL999054.1  Strongyloides stercoralis genome assembly S_sterco...  53.6    0.007
# LM523244.1  Parastrongyloides trichosuri genome assembly P_tri...  53.6    0.007
# LN609398.1  Strongyloides ratti genome assembly S_ratti_ED321,...  53.6    0.007
# HG975444.1  Solanum pennellii chromosome ch05, complete genome     53.6    0.007
# HG975440.1  Solanum pennellii chromosome ch01, complete genome     53.6    0.007
# EU925743.1  Nucula sp. AL-2008 satellite NUC005 sequence           53.6    0.007
# EU925738.1  Nucula sp. AL-2008 satellite NUC001 sequence           53.6    0.007
# XM_020010563.1  PREDICTED: Aethina tumida uncharacterized LOC1...  51.8    0.023
# AP015041.1  Vigna angularis var. angularis DNA, chromosome 8, ...  51.8    0.023
# CP012622.1  Spiroplasma cantharicola strain CC-1, complete genome  51.8    0.023
# XM_013340608.1  PREDICTED: Amyelois transitella mitogen-activa...  51.8    0.023
# LL999087.1  Strongyloides stercoralis genome assembly S_sterco...  51.8    0.023
# LL999073.1  Strongyloides stercoralis genome assembly S_sterco...  51.8    0.023
# LM725909.1  Protopolystoma xenopodis genome assembly P_xenopod...  51.8    0.023
# LN591229.1  Cyprinus carpio genome assembly common carp genome...  51.8    0.023
# HG975523.1  Solanum lycopersicum chromosome ch11, complete genome  51.8    0.023
# KJ477073.1  Mytilus chilensis microsatellite Mch-UCH48 sequence    51.8    0.023
# AM444115.2  Vitis vinifera contig VV78X139010.2, whole genome ...  51.8    0.023
# AM432216.1  Vitis vinifera contig VV78X214798.14, whole genome...  51.8    0.023
# BX005210.10  Zebrafish DNA sequence from clone DKEY-222F8 in l...  51.8    0.023
# KX943418.1  Longitarsus exsoletus mitochondrion, partial genome    50.0    0.081
# LT669794.1  Arabis alpina genome assembly, chromosome: chr7        50.0    0.081
# KX356680.1  Achatinella sowerbyana mitochondrion, complete genome  50.0    0.081
# CP013714.1  Staphylococcus equorum strain C2014, complete genome   50.0    0.081
# CP012968.1  Staphylococcus sp. AntiMn-1, complete genome           50.0    0.081
# XM_016712493.1  PREDICTED: Capsicum annuum polyadenylate-bindi...  50.0    0.081
# AP015043.1  Vigna angularis var. angularis DNA, chromosome 10,...  50.0    0.081
# CP013114.1  Staphylococcus equorum strain KS1039, complete genome  50.0    0.081
# KT037718.1  Azumapecten farreri isolate CFBTB-G Rho GTPase gen...  50.0    0.081
# XM_014115907.1  PREDICTED: Canis lupus familiaris thioredoxin ...  50.0    0.081
# XM_005623403.2  PREDICTED: Canis lupus familiaris thioredoxin ...  50.0    0.081
# LN831025.1  Campylobacter jejuni genome assembly NCTC11351, ch...  50.0    0.081
# Query= scaffold126195-1416
#
# Length=1002
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# LL710374.1  Elaeophora elaphi genome assembly E_elaphi, scaffo...  59.0    2e-04
# LT594502.1  Plasmodium malariae genome assembly, chromosome: 14    50.0    0.081
# LT594796.1  Theobroma cacao genome assembly, chromosome: IX        50.0    0.081
# AP015036.1  Vigna angularis var. angularis DNA, chromosome 3, ...  50.0    0.081
# AP015039.1  Vigna angularis var. angularis DNA, chromosome 6, ...  50.0    0.081
# CP011892.1  Ovis canadensis canadensis isolate 43U chromosome ...  50.0    0.081
# LM523460.1  Parastrongyloides trichosuri genome assembly P_tri...  50.0    0.081
# LN598090.1  Cyprinus carpio genome assembly common carp genome...  50.0    0.081
# LN590691.1  Cyprinus carpio genome assembly common carp genome...  50.0    0.081
# CP006721.1  Clostridium saccharobutylicum DSM 13864, complete ...  50.0    0.081
# HE601625.1  Schistosoma mansoni strain Puerto Rico chromosome ...  50.0    0.081
# FP236838.1  Microcebus murinus natural killer complex (NKC) ha...  50.0    0.081
# CU062432.8  Zebrafish DNA sequence from clone DKEY-276F17 in l...  50.0    0.081
# BX537119.5  Zebrafish DNA sequence from clone DKEY-88G13 in li...  50.0    0.081
# AL772373.23  Zebrafish DNA sequence from clone CH211-143A22 in...  50.0    0.081
# XM_014492288.1  PREDICTED: Latimeria chalumnae putative ammoni...  48.2    0.28
# XM_014492287.1  PREDICTED: Latimeria chalumnae putative ammoni...  48.2    0.28
# XM_014492286.1  PREDICTED: Latimeria chalumnae putative ammoni...  48.2    0.28
# CP012387.1  Mycoplasma mycoides subsp. capri strain GM12 clone...  48.2    0.28
# XM_013249727.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249726.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249725.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249724.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249723.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249722.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249721.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249720.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# XM_013249719.1  PREDICTED: Stomoxys calcitrans serine/threonin...  48.2    0.28
# LM524968.1  Strongyloides venezuelensis genome assembly S_vene...  48.2    0.28
# XM_011692881.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# XM_011692880.1  PREDICTED: Wasmannia auropunctata uncharacteri...  48.2    0.28
# LK965102.1  Brugia pahangi genome assembly B_pahangi_Glasgow, ...  48.2    0.28
# LM525555.1  Strongyloides papillosus genome assembly S_papillo...  48.2    0.28
# LM098831.1  Schistosoma curassoni genome assembly S_curassoni_...  48.2    0.28
# FQ377874.1  Mycoplasma mycoides subsp. capri LC str. 95010 chr...  48.2    0.28
# CP002027.1  Synthetic Mycoplasma mycoides JCVI-syn1.0 clone sM...  48.2    0.28
# CP001621.1  Mycoplasma mycoides subsp. capri str. GM12 transge...  48.2    0.28
# CP001668.1  Mycoplasma mycoides subsp. capri str. GM12 transge...  48.2    0.28
# BT053272.1  Medicago truncatula clone MTYFP_FQ_FR_FS1G-P-21 un...  48.2    0.28
# AM446085.2  Vitis vinifera contig VV78X272490.3, whole genome ...  48.2    0.28
# AM428663.2  Vitis vinifera contig VV78X020635.9, whole genome ...  48.2    0.28
# XM_001437190.1  Paramecium tetraurelia hypothetical protein (G...  48.2    0.28
# CT737192.10  Zebrafish DNA sequence from clone DKEYP-106E12 in...  48.2    0.28
# CP009471.1  Marinitoga sp. 1137, complete genome                   46.4    0.99
# LN835309.1  Plasmodium relictum strain SGS1 genome assembly, c...  46.4    0.99
# LT594635.1  Plasmodium malariae genome assembly, chromosome: 14    46.4    0.99
# LT608277.1  Plasmodium berghei strain SP11 RLL genome assembly...  46.4    0.99
# LT608261.1  Plasmodium berghei strain SP11 Antwerpcl1 genome a...  46.4    0.99
# LT614639.1  Plasmodium berghei strain NK65e genome assembly, c...  46.4    0.99
# LT608149.1  Plasmodium berghei strain NK65 ny genome assembly,...  46.4    0.99
# Query= scaffold128214-5365
#
# Length=771
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# LL891247.1  Schistosoma margrebowiei genome assembly S_margreb...  51.8    0.023
# CR339062.17  Zebrafish DNA sequence from clone CH211-285J22 in...  51.8    0.023
# KF740500.1  Paphia amabilis microsatellite Pam33 sequence          50.0    0.081
# LL999052.1  Strongyloides stercoralis genome assembly S_sterco...  50.0    0.081
# BT052292.1  Medicago truncatula clone MTYF9_FA_FB_FC1G-P-24 un...  50.0    0.081
# LT669790.1  Arabis alpina genome assembly, chromosome: chr3        46.4    0.99
# LT635757.1  [Candida] intermedia strain CBS 141442 genome asse...  46.4    0.99
# XM_015831449.1  PREDICTED: Protobothrops mucrosquamatus integr...  46.4    0.99
# AP015043.1  Vigna angularis var. angularis DNA, chromosome 10,...  46.4    0.99
# XM_014399947.1  PREDICTED: Cimex lectularius sorting nexin-9 (...  46.4    0.99
# LK065428.1  Apteryx australis mantelli genome assembly AptMant...  46.4    0.99
# LL878071.1  Schistosoma margrebowiei genome assembly S_margreb...  46.4    0.99
# LL877372.1  Schistosoma margrebowiei genome assembly S_margreb...  46.4    0.99
# LL239007.1  Echinostoma caproni genome assembly E_caproni_Egyp...  46.4    0.99
# LM065374.1  Schistosoma curassoni genome assembly S_curassoni_...  46.4    0.99
# LM523158.1  Parastrongyloides trichosuri genome assembly P_tri...  46.4    0.99
# LM002280.1  Wuchereria bancrofti genome assembly W_bancrofti_J...  46.4    0.99
# LM993667.1  Plasmodium yoelii genome assembly PY17X01, chromos...  46.4    0.99
# LK934641.1  Plasmodium yoelii genome assembly PYYM01, chromoso...  46.4    0.99
# XM_006418770.1  Eutrema salsugineum hypothetical protein (EUTS...  46.4    0.99
# APGK01045303.1  Dendroctonus ponderosae Seq01045313, whole gen...  46.4    0.99
# AM450208.1  Vitis vinifera, whole genome shotgun sequence, con...  46.4    0.99
# CR854891.10  Zebrafish DNA sequence from clone DKEY-52P2 in li...  46.4    0.99
# AC097513.2  Homo sapiens BAC clone RP11-419E3 from 4, complete...  46.4    0.99
# AC104840.2  Homo sapiens BAC clone RP11-10E9 from 4, complete ...  46.4    0.99
# AF105139.1  Brassica napus chromosome N11 GTP-binding protein ...  46.4    0.99
# CP012814.1  Saccharomycopsis fibuligera x Saccharomycopsis cf....  44.6    3.5
# CP015983.1  Saccharomycopsis fibuligera strain ATCC 36309 chro...  44.6    3.5
# CP012828.1  Saccharomycopsis fibuligera strain KPH12 chromosom...  44.6    3.5
# XR_441661.3  PREDICTED: Felis catus uncharacterized LOC1029003...  44.6    3.5
# LN835306.1  Plasmodium relictum strain SGS1 genome assembly, c...  44.6    3.5
# CP017456.1  Campylobacter jejuni subsp. jejuni str. RM3420, co...  44.6    3.5
# LT594635.1  Plasmodium malariae genome assembly, chromosome: 14    44.6    3.5
# LT608207.1  Plasmodium chabaudi adami strain DK genome assembl...  44.6    3.5
# LT608165.1  Plasmodium chabaudi chabaudi strain CB genome asse...  44.6    3.5
# LT608193.1  Plasmodium chabaudi adami strain DS genome assembl...  44.6    3.5
# LT608179.1  Plasmodium chabaudi chabaudi strain AJ genome asse...  44.6    3.5
# CP015209.1  Campylobacter jejuni subsp. jejuni strain RM1285, ...  44.6    3.5
# LT594791.1  Theobroma cacao genome assembly, chromosome: IV        44.6    3.5
# LT594789.1  Theobroma cacao genome assembly, chromosome: II        44.6    3.5
# LT594788.1  Theobroma cacao genome assembly, chromosome: I         44.6    3.5
# AP015041.1  Vigna angularis var. angularis DNA, chromosome 8, ...  44.6    3.5
# AP015039.1  Vigna angularis var. angularis DNA, chromosome 6, ...  44.6    3.5
# XM_013242257.1  PREDICTED: Stomoxys calcitrans protein hairles...  44.6    3.5
# XM_013242256.1  PREDICTED: Stomoxys calcitrans protein hairles...  44.6    3.5
# XM_013242255.1  PREDICTED: Stomoxys calcitrans protein hairles...  44.6    3.5
# XM_013242254.1  PREDICTED: Stomoxys calcitrans protein hairles...  44.6    3.5
# XM_004741939.2  PREDICTED: Mustela putorius furo transmembrane...  44.6    3.5
# CP011886.1  Ovis canadensis canadensis isolate 43U chromosome ...  44.6    3.5
# CP011901.1  Ovis canadensis canadensis isolate 43U chromosome ...  44.6    3.5
# Query= scaffold129719-115XX
#
# Length=569
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# LN596638.1  Cyprinus carpio genome assembly common carp genome...  53.6    0.007
# XR_001475804.1  PREDICTED: Polistes dominula histone-arginine ...  50.0    0.081
# XM_015322073.1  PREDICTED: Polistes dominula histone-arginine ...  50.0    0.081
# XM_014755343.1  PREDICTED: Polistes canadensis histone-arginin...  50.0    0.081
# XR_001382078.1  PREDICTED: Polistes canadensis histone-arginin...  50.0    0.081
# XM_014755342.1  PREDICTED: Polistes canadensis histone-arginin...  50.0    0.081
# LN713259.1  Cucumis melo genomic chromosome, chr_5                 48.2    0.28
# LN681842.1  Cucumis melo genomic scaffold, anchoredscaffold00022   48.2    0.28
# KU550083.1  Paracoccus ferrisi isolate 13M128 cytochrome oxida...  46.4    0.99
# KU550082.1  Paracoccus ferrisi isolate 13M127 cytochrome oxida...  46.4    0.99
# XM_016446116.1  PREDICTED: Sinocyclocheilus anshuiensis voltag...  46.4    0.99
# LM525067.1  Strongyloides venezuelensis genome assembly S_vene...  46.4    0.99
# LN592427.1  Cyprinus carpio genome assembly common carp genome...  46.4    0.99
# AL135745.5  Human chromosome 14 DNA sequence BAC C-2300N4 of l...  46.4    0.99
# XM_011199537.2  PREDICTED: Bactrocera dorsalis long-chain-fatt...  44.6    3.5
# KT959496.1  Rimapenaeus constrictus voucher SERCINVERT0179 16S...  44.6    3.5
# LT622864.1  Dichotomaria marginata chloroplast, complete genom...  44.6    3.5
# KT755809.1  Heuchera longipetala var. longipetala isolate Yaha...  44.6    3.5
# KX162769.1  Rimapenaeus similis voucher NTOU M02022 16S riboso...  44.6    3.5
# AP015035.1  Vigna angularis var. angularis DNA, chromosome 2, ...  44.6    3.5
# XM_014937775.1  PREDICTED: Calidris pugnax diphthamide biosynt...  44.6    3.5
# XM_014937773.1  PREDICTED: Calidris pugnax diphthamide biosynt...  44.6    3.5
# XM_014247072.1  PREDICTED: Bactrocera oleae peptide transporte...  44.6    3.5
# CP011890.1  Ovis canadensis canadensis isolate 43U chromosome ...  44.6    3.5
# XM_001014078.4  Tetrahymena thermophila SB210 anaphase-promoti...  44.6    3.5
# CP010049.1  Blochmannia endosymbiont of Camponotus (Colobopsis...  44.6    3.5
# LM752646.1  Protopolystoma xenopodis genome assembly P_xenopod...  44.6    3.5
# LM403164.1  Hymenolepis nana genome assembly H_nana_Japan, sca...  44.6    3.5
# LK979682.1  Thelazia callipaeda genome assembly T_callipaeda_T...  44.6    3.5
# LN592391.1  Cyprinus carpio genome assembly common carp genome...  44.6    3.5
# LN591215.1  Cyprinus carpio genome assembly common carp genome...  44.6    3.5
# LN590690.1  Cyprinus carpio genome assembly common carp genome...  44.6    3.5
# LN590681.1  Cyprinus carpio genome assembly common carp genome...  44.6    3.5
# HG975523.1  Solanum lycopersicum chromosome ch11, complete genome  44.6    3.5
# JN954500.1  Mus musculus targeted non-conditional, lacZ-tagged...  44.6    3.5
# JN950550.1  Mus musculus targeted KO-first, conditional ready,...  44.6    3.5
# CP001719.1  Methanobrevibacter ruminantium M1, complete genome     44.6    3.5
# AC238626.1  Carica papaya BAC clone 80F18, complete sequence       44.6    3.5
# AM458204.2  Vitis vinifera contig VV78X196632.2, whole genome ...  44.6    3.5
# AY622215.1  Rimapenaeus similis 16S ribosomal RNA gene, partia...  44.6    3.5
# AY622212.1  Rimapenaeus constrictus 16S ribosomal RNA gene, pa...  44.6    3.5
# AC118747.5  Mus musculus chromosome 5, clone RP24-194J1, compl...  44.6    3.5
# AC149631.3  Rhinolophus ferrumequinum clone VMRC7-80B12, compl...  44.6    3.5
# AC158786.8  Mus musculus chromosome 5, clone RP23-228M24, comp...  44.6    3.5
# AL929044.17  Zebrafish DNA sequence from clone CH211-245D9 in ...  44.6    3.5
# CR381602.30  Zebrafish DNA sequence from clone DKEY-183M22 in ...  44.6    3.5
# AC117482.4  Homo sapiens 3 BAC RP11-651J20 (Roswell Park Cance...  44.6    3.5
# AC107025.3  Homo sapiens 3 BAC RP11-474M18 (Roswell Park Cance...  44.6    3.5
# AL844533.11  Mouse DNA sequence from clone RP23-299K8 on chrom...  44.6    3.5
# AL935047.12  Zebrafish DNA sequence from clone DKEY-20L10 in l...  44.6    3.5
# Query= scaffold130369-15322
#
# Length=1099
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# KJ460346.1  Panopea globosa microsatellite PglobT41 sequence       80.6    5e-11
# JX416878.1  Panopea abbreviata voucher MNCN Pa5 microsatellite...  75.2    2e-09
# KX355771.1  Panopea globosa microsatellite Pglo4_5 sequence        71.6    2e-08
# KJ460347.1  Panopea globosa microsatellite PglobT46 sequence       71.6    2e-08
# AF541257.1  Panopea abrupta microsatellite Pab8 sequence           71.6    2e-08
# KJ460337.1  Panopea globosa microsatellite PglobT17 sequence       62.6    1e-05
# LM164866.1  Schistosoma mattheei genome assembly S_mattheei_De...  55.4    0.002
# LM067701.1  Schistosoma curassoni genome assembly S_curassoni_...  55.4    0.002
# AP015041.1  Vigna angularis var. angularis DNA, chromosome 8, ...  53.6    0.007
# LL883453.1  Schistosoma margrebowiei genome assembly S_margreb...  51.8    0.023
# LT669792.1  Arabis alpina genome assembly, chromosome: chr5        50.0    0.081
# XM_015974794.1  PREDICTED: Nothobranchius furzeri alpha-methyl...  50.0    0.081
# XR_001572659.1  PREDICTED: Nothobranchius furzeri uncharacteri...  50.0    0.081
# XM_015909082.1  PREDICTED: Acropora digitifera uncharacterized...  50.0    0.081
# XM_015619779.1  PREDICTED: Parus major receptor interacting se...  50.0    0.081
# XM_005517043.2  PREDICTED: Pseudopodoces humilis receptor-inte...  50.0    0.081
# LL877075.1  Schistosoma margrebowiei genome assembly S_margreb...  50.0    0.081
# CR318659.26  Zebrafish DNA sequence from clone CH211-215M5 in ...  50.0    0.081
# LT594593.1  Plasmodium ovale genome assembly, chromosome: 12       48.2    0.28
# LT594634.1  Plasmodium malariae genome assembly, chromosome: 13    48.2    0.28
# LT594516.1  Plasmodium ovale genome assembly, chromosome: 12       48.2    0.28
# LT594501.1  Plasmodium malariae genome assembly, chromosome: 13    48.2    0.28
# XR_001686120.1  PREDICTED: Gossypium hirsutum uncharacterized ...  48.2    0.28
# LT160000.1  Macaca fascicularis complete genome, chromosome chr1   48.2    0.28
# AP014963.1  Oryza sativa Japonica Group DNA, chromosome 7, cul...  48.2    0.28
# LL064350.1  Trichobilharzia regenti genome assembly T_regenti_...  48.2    0.28
# LK975495.1  Brugia pahangi genome assembly B_pahangi_Glasgow, ...  48.2    0.28
# LK969379.1  Brugia pahangi genome assembly B_pahangi_Glasgow, ...  48.2    0.28
# LM000577.1  Wuchereria bancrofti genome assembly W_bancrofti_J...  48.2    0.28
# LN590718.1  Cyprinus carpio genome assembly common carp genome...  48.2    0.28
# NM_001019123.2  Schizosaccharomyces pombe 972h- N-acetyl-gamma...  48.2    0.28
# JX416886.1  Panopea abbreviata voucher MNCN Pa5 microsatellite...  48.2    0.28
# CU329670.1  Schizosaccharomyces pombe chromosome I, complete s...  48.2    0.28
# AM429776.2  Vitis vinifera contig VV78X073209.8, whole genome ...  48.2    0.28
# CR388068.18  Zebrafish DNA sequence from clone CH211-284A6 in ...  48.2    0.28
# CR352217.9  Zebrafish DNA sequence from clone CH211-129P13 in ...  48.2    0.28
# AP004668.3  Oryza sativa Japonica Group genomic DNA, chromosom...  48.2    0.28
# AP003802.2  Oryza sativa Japonica Group genomic DNA, chromosom...  48.2    0.28
# BX296561.8  Zebrafish DNA sequence from clone CH211-145F17 in ...  48.2    0.28
# X63576.1  S.pombe arg11 gene for acetylglutamate kinase & N-ac...  48.2    0.28
# CP019389.1  Seonamhaeicola sp. S2-3, complete genome               46.4    0.99
# CP017962.1  Virgibacillus halodenitrificans strain PDB-F2, com...  46.4    0.99
# LT608274.1  Plasmodium berghei strain SP11 RLL genome assembly...  46.4    0.99
# LT608258.1  Plasmodium berghei strain SP11 Antwerpcl1 genome a...  46.4    0.99
# LT614636.1  Plasmodium berghei strain NK65e genome assembly, c...  46.4    0.99
# LT608146.1  Plasmodium berghei strain NK65 ny genome assembly,...  46.4    0.99
# XM_016341911.1  PREDICTED: Arachis ipaensis uncharacterized LO...  46.4    0.99
# XM_015964924.1  PREDICTED: Nothobranchius furzeri uncharacteri...  46.4    0.99
# XM_015946049.1  PREDICTED: Nothobranchius furzeri zinc finger ...  46.4    0.99
# XM_015946048.1  PREDICTED: Nothobranchius furzeri zinc finger ...  46.4    0.99
# Query= scaffold13704-29380
#
# Length=1035
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# HG975451.1  Solanum pennellii chromosome ch12, complete genome     64.4    4e-06
# XM_003247016.3  PREDICTED: Acyrthosiphon pisum amyloid beta A4...  62.6    1e-05
# XM_015998677.1  PREDICTED: Peromyscus maniculatus bairdii mito...  60.8    4e-05
# NG_013325.2  Homo sapiens mitogen-activated protein kinase 10 ...  59.0    2e-04
# XM_012902968.1  Acytostelium subglobosum LB1 hypothetical prot...  59.0    2e-04
# XM_012898006.1  Acytostelium subglobosum LB1 hypothetical prot...  59.0    2e-04
# LL999049.1  Strongyloides stercoralis genome assembly S_sterco...  59.0    2e-04
# XM_004356156.1  Dictyostelium fasciculatum hypothetical protei...  59.0    2e-04
# GU904534.1  Dictyostelium giganteum clone Dicty_1K20 microsate...  59.0    2e-04
# XM_629770.2  Dictyostelium discoideum AX4 ubiquitin protein li...  59.0    2e-04
# XM_642233.1  Dictyostelium discoideum AX4 hypothetical protein...  59.0    2e-04
# XM_636370.1  Dictyostelium discoideum AX4 hypothetical protein...  59.0    2e-04
# XM_635691.1  Dictyostelium discoideum AX4 paired amphipathic h...  59.0    2e-04
# AC104827.4  Homo sapiens BAC clone RP11-778J15 from 4, complet...  59.0    2e-04
# CR855373.6  Zebrafish DNA sequence from clone CH73-124C24 in l...  59.0    2e-04
# CP012816.1  Saccharomycopsis fibuligera x Saccharomycopsis cf....  57.2    5e-04
# XM_009114262.2  PREDICTED: Brassica rapa KH domain-containing ...  57.2    5e-04
# CP005335.2  Saccharomyces cerevisiae YJM1250 chromosome XI seq...  57.2    5e-04
# AC270611.1  Pan troglodytes chromosome 2 clone CH251-19L3, com...  57.2    5e-04
# XM_014377571.1  PREDICTED: Trichogramma pretiosum potassium vo...  57.2    5e-04
# XM_014377570.1  PREDICTED: Trichogramma pretiosum potassium vo...  57.2    5e-04
# LM780398.1  Protopolystoma xenopodis genome assembly P_xenopod...  57.2    5e-04
# LL901361.1  Schistocephalus solidus genome assembly S_solidus_...  57.2    5e-04
# LL036836.1  Trichobilharzia regenti genome assembly T_regenti_...  57.2    5e-04
# XM_009027181.1  Helobdella robusta hypothetical protein mRNA       57.2    5e-04
# XM_009022875.1  Helobdella robusta hypothetical protein partia...  57.2    5e-04
# LL710917.1  Elaeophora elaphi genome assembly E_elaphi, scaffo...  57.2    5e-04
# HG975519.1  Solanum lycopersicum chromosome ch07, complete genome  57.2    5e-04
# HG975518.1  Solanum lycopersicum chromosome ch06, complete genome  57.2    5e-04
# HG975515.1  Solanum lycopersicum chromosome ch03, complete genome  57.2    5e-04
# HG975449.1  Solanum pennellii chromosome ch10, complete genome     57.2    5e-04
# HG975446.1  Solanum pennellii chromosome ch07, complete genome     57.2    5e-04
# HG975443.1  Solanum pennellii chromosome ch04, complete genome     57.2    5e-04
# XM_003286673.1  Dictyostelium purpureum hypothetical protein, ...  57.2    5e-04
# CU695177.10  Zebrafish DNA sequence from clone CH73-367J22 in ...  57.2    5e-04
# AC172879.2  Brassica rapa subsp. pekinensis clone KBrH070I10, ...  57.2    5e-04
# AC196248.3  Pan troglodytes BAC clone CH251-328D3 from chromos...  57.2    5e-04
# CU179730.13  Zebrafish DNA sequence from clone CH211-186I18 in...  57.2    5e-04
# AC194748.3  Pan troglodytes BAC clone CH251-71L9 from chromoso...  57.2    5e-04
# XM_641948.1  Dictyostelium discoideum AX4 hypothetical protein...  57.2    5e-04
# XM_639221.1  Dictyostelium discoideum AX4 RING zinc finger-con...  57.2    5e-04
# XM_638757.1  Dictyostelium discoideum AX4 DOCK family protein ...  57.2    5e-04
# XM_638191.1  Dictyostelium discoideum AX4 hypothetical protein...  57.2    5e-04
# BX511080.4  Zebrafish DNA sequence from clone DKEY-237N7 in li...  57.2    5e-04
# AL954812.14  Zebrafish DNA sequence from clone DKEY-50G15, com...  57.2    5e-04
# AL954689.16  Zebrafish DNA sequence from clone DKEYP-51G2 in l...  57.2    5e-04
# NG_007520.1  Oikopleura dioica BAC clone OIKO005, complete seq...  57.2    5e-04
# BX324157.4  Zebrafish DNA sequence from clone DKEY-15N1 in lin...  57.2    5e-04
# AL627122.18  Mouse DNA sequence from clone RP23-132E8 on chrom...  57.2    5e-04
# AL772285.9  Mouse DNA sequence from clone RP23-76I24 on chromo...  57.2    5e-04
# Query= scaffold147711-174
#
# Length=445
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# AP015036.1  Vigna angularis var. angularis DNA, chromosome 3, ...  50.0    0.081
# LK914223.1  Brugia timori genome assembly B_timori_Indonesia_v...  50.0    0.081
# HF933230.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  48.2    0.28
# XM_015354199.1  PREDICTED: Lepisosteus oculatus arachidonate 8...  48.2    0.28
# LM525021.1  Strongyloides venezuelensis genome assembly S_vene...  48.2    0.28
# LL999097.1  Strongyloides stercoralis genome assembly S_sterco...  48.2    0.28
# LK964384.1  Brugia pahangi genome assembly B_pahangi_Glasgow, ...  48.2    0.28
# FP929048.1  Megamonas hypermegale ART12/1 draft genome             48.2    0.28
# CP017000.1  Plasmodium falciparum 3D7 chromosome 10 sequence       46.4    0.99
# LN999944.1  Plasmodium falciparum 3D7 chromosome 10, complete ...  46.4    0.99
# CP011895.1  Ovis canadensis canadensis isolate 43U chromosome ...  46.4    0.99
# LM525000.1  Strongyloides venezuelensis genome assembly S_vene...  46.4    0.99
# XM_003492555.2  PREDICTED: Bombus impatiens LETM1 domain-conta...  46.4    0.99
# KJ839702.1  Lasioglossum lissonotum voucher BC ZSM HYM 07712 c...  46.4    0.99
# XM_009905342.1  PREDICTED: Picoides pubescens latrophilin 2 (L...  46.4    0.99
# LM384335.1  Hymenolepis diminuta genome assembly H_diminuta_De...  46.4    0.99
# LL319998.1  Anisakis simplex genome assembly A_simplex, scaffo...  46.4    0.99
# LK979619.1  Thelazia callipaeda genome assembly T_callipaeda_T...  46.4    0.99
# LK978226.1  Dracunculus medinensis genome assembly D_medinensi...  46.4    0.99
# LK964521.1  Brugia pahangi genome assembly B_pahangi_Glasgow, ...  46.4    0.99
# LK907617.1  Brugia timori genome assembly B_timori_Indonesia_v...  46.4    0.99
# LN592105.1  Cyprinus carpio genome assembly common carp genome...  46.4    0.99
# LN590711.1  Cyprinus carpio genome assembly common carp genome...  46.4    0.99
# XM_008490827.1  PREDICTED: Calypte anna latrophilin 2 (LPHN2),...  46.4    0.99
# XM_008490826.1  PREDICTED: Calypte anna latrophilin 2 (LPHN2),...  46.4    0.99
# CU302206.11  Zebrafish DNA sequence from clone DKEY-9F16 in li...  46.4    0.99
# CP002690.1  Thermodesulfobium narugense DSM 14796, complete ge...  46.4    0.99
# FJ823227.1  Cephalonomia gallicola mitochondrion, partial genome   46.4    0.99
# CU462909.5  Zebrafish DNA sequence from clone RP71-8I12 in lin...  46.4    0.99
# AM458391.2  Vitis vinifera contig VV78X257459.3, whole genome ...  46.4    0.99
# XM_001347432.1  Plasmodium falciparum 3D7 eukaryotic translati...  46.4    0.99
# LT635772.1  Anaerococcus sp. Marseille-P2765 strain Marseille-...  44.6    3.5
# XM_019058722.1  PREDICTED: Bemisia tabaci USP6 N-terminal-like...  44.6    3.5
# XM_019051231.1  PREDICTED: Bemisia tabaci uncharacterized LOC1...  44.6    3.5
# XM_018785336.1  Plasmodium gaboni protein kinase 1 partial mRNA    44.6    3.5
# KX374826.1  Lasioglossum parvulum isolate STO-13-5 cytochrome ...  44.6    3.5
# KX374817.1  Lasioglossum calceatum isolate SCH-19-5 cytochrome...  44.6    3.5
# KX374816.1  Lasioglossum calceatum isolate SCH-19-3 cytochrome...  44.6    3.5
# KX374815.1  Lasioglossum calceatum isolate STE-4-4 cytochrome ...  44.6    3.5
# KX374814.1  Lasioglossum calceatum isolate STE-4-3 cytochrome ...  44.6    3.5
# KX374813.1  Lasioglossum calceatum isolate STE-4-2 cytochrome ...  44.6    3.5
# KX374812.1  Lasioglossum calceatum isolate STE-4-1 cytochrome ...  44.6    3.5
# KX374811.1  Lasioglossum calceatum isolate ZOR-8-5 cytochrome ...  44.6    3.5
# KX374810.1  Lasioglossum calceatum isolate ZOR-8-3 cytochrome ...  44.6    3.5
# KX374809.1  Lasioglossum calceatum isolate ZOR-7-1 cytochrome ...  44.6    3.5
# KX374808.1  Lasioglossum calceatum isolate ASCH-21 cytochrome ...  44.6    3.5
# KX374807.1  Lasioglossum calceatum isolate LIN-9-6 cytochrome ...  44.6    3.5
# KX374806.1  Lasioglossum calceatum isolate LIN-9-5 cytochrome ...  44.6    3.5
# KX374804.1  Lasioglossum calceatum isolate LIN-9-3 cytochrome ...  44.6    3.5
# KX374803.1  Lasioglossum calceatum isolate LIN-9-2 cytochrome ...  44.6    3.5
# Query= scaffold16116-7076
#
# Length=1130
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# XM_011215019.2  PREDICTED: Bactrocera dorsalis tubulin beta-3 ...  77.0    6e-10
# XM_012018347.1  PREDICTED: Vollenhovia emeryi histone-lysine N...  77.0    6e-10
# XM_012005179.1  PREDICTED: Vollenhovia emeryi putative unchara...  77.0    6e-10
# XM_012002878.1  PREDICTED: Vollenhovia emeryi putative unchara...  77.0    6e-10
# XM_012019428.1  PREDICTED: Vollenhovia emeryi putative unchara...  77.0    6e-10
# XM_013340419.1  PREDICTED: Amyelois transitella NADPH--cytochr...  75.2    2e-09
# XM_012008227.1  PREDICTED: Vollenhovia emeryi putative unchara...  73.4    7e-09
# XM_012003757.1  PREDICTED: Vollenhovia emeryi putative unchara...  73.4    7e-09
# XM_011068030.1  PREDICTED: Acromyrmex echinatior uncharacteriz...  73.4    7e-09
# XM_011054755.1  PREDICTED: Acromyrmex echinatior splicing fact...  73.4    7e-09
# FJ710597.1  Ceratitis capitata clone eve.ceratitis_capitata.FC...  73.4    7e-09
# FJ710569.1  Ceratitis capitata clone Ccap_evefos2.scaffold_0 C...  73.4    7e-09
# XM_018472243.1  PREDICTED: Agrilus planipennis O-acetyl-ADP-ri...  68.0    3e-07
# XM_018510782.1  PREDICTED: Trachymyrmex cornetzi putative unch...  66.2    1e-06
# XM_011254802.2  PREDICTED: Camponotus floridanus leucine-rich ...  64.4    4e-06
# XM_011254801.2  PREDICTED: Camponotus floridanus leucine-rich ...  64.4    4e-06
# XM_018520872.1  PREDICTED: Trachymyrmex cornetzi uncharacteriz...  64.4    4e-06
# XM_018468959.1  PREDICTED: Agrilus planipennis cGMP-dependent ...  64.4    4e-06
# LN554858.1  Tapinoma nigerrimum Azteca mariner-like transposon...  64.4    4e-06
# XM_014615281.1  PREDICTED: Dinoponera quadriceps cell death-in...  64.4    4e-06
# XM_018475328.1  PREDICTED: Agrilus planipennis uncharacterized...  62.6    1e-05
# XM_018475327.1  PREDICTED: Agrilus planipennis uncharacterized...  62.6    1e-05
# BK008406.1  TPA: Harpegnathos saltator defensin-1 gene, comple...  62.6    1e-05
# EU365789.1  Drosophila yakuba strain CY27 tan gene, 5' upstrea...  62.6    1e-05
# KX930995.1  Bactrocera tryoni transposon Batmar24 putative DD3...  60.8    4e-05
# XM_014629921.1  PREDICTED: Dinoponera quadriceps putative unch...  60.8    4e-05
# XM_011703537.1  PREDICTED: Wasmannia auropunctata probable G-p...  60.8    4e-05
# XM_011261597.2  PREDICTED: Camponotus floridanus putative unch...  59.0    2e-04
# XM_013344212.1  PREDICTED: Amyelois transitella histone-lysine...  59.0    2e-04
# AC238785.1  Phlebotomus papatasi BAC clone PLPAAEX-6H12 from c...  59.0    2e-04
# XM_011351577.2  PREDICTED: Cerapachys biroi mariner Mos1 trans...  57.2    5e-04
# XM_011145322.2  PREDICTED: Harpegnathos saltator uncharacteriz...  57.2    5e-04
# XM_018477724.1  PREDICTED: Agrilus planipennis histone-lysine ...  55.4    0.002
# XM_018463347.1  PREDICTED: Agrilus planipennis protein scarlet...  55.4    0.002
# XM_012208281.1  PREDICTED: Atta cephalotes histone-lysine N-me...  55.4    0.002
# XM_012005483.1  PREDICTED: Vollenhovia emeryi caspase-8 (LOC10...  55.4    0.002
# XM_011067966.1  PREDICTED: Acromyrmex echinatior putative unch...  55.4    0.002
# LL199078.1  Heligmosomoides polygyrus genome assembly H_bakeri...  55.4    0.002
# LL197908.1  Heligmosomoides polygyrus genome assembly H_bakeri...  55.4    0.002
# LK765626.1  Dicrocoelium dendriticum genome assembly D_dendrit...  55.4    0.002
# XM_014623111.1  PREDICTED: Dinoponera quadriceps histone-lysin...  53.6    0.007
# XM_011254782.1  PREDICTED: Camponotus floridanus histone-lysin...  53.6    0.007
# LM532015.1  Mesocestoides corti genome assembly M_corti_Specht...  53.6    0.007
# LL189517.1  Heligmosomoides polygyrus genome assembly H_bakeri...  53.6    0.007
# XM_018475102.1  PREDICTED: Agrilus planipennis uncharacterized...  51.8    0.023
# XM_018030765.1  PREDICTED: Ceratina calcarata UDP-glucuronosyl...  51.8    0.023
# XM_015929217.1  PREDICTED: Tetranychus urticae histone-lysine ...  51.8    0.023
# XM_012202298.1  PREDICTED: Atta cephalotes histone-lysine N-me...  51.8    0.023
# LM436734.1  Nippostrongylus brasiliensis genome assembly N_bra...  51.8    0.023
# LM405953.1  Hymenolepis nana genome assembly H_nana_Japan, sca...  51.8    0.023
# Query= scaffold176442-9109
#
# Length=919
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# XM_006423915.1  Citrus clementina hypothetical protein (CICLE_...  50.0    0.081
# HQ827835.1  Oryza minuta isolate BC_B Shattering4 gene locus, ...  48.2    0.28
# HF933220.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  46.4    0.99
# LM408050.1  Hymenolepis nana genome assembly H_nana_Japan, sca...  46.4    0.99
# HG975521.1  Solanum lycopersicum chromosome ch09, complete genome  46.4    0.99
# HG670306.1  Triticum aestivum chromosome 3B, genomic scaffold,...  44.6    3.5
# XM_005503327.1  PREDICTED: Columba livia G protein-coupled rec...  44.6    3.5
# HE601631.1  Schistosoma mansoni strain Puerto Rico chromosome ...  44.6    3.5
# CP002583.1  Marinomonas mediterranea MMB-1, complete genome        44.6    3.5
# AC193015.3  Pan troglodytes BAC clone CH251-174B19 from chromo...  44.6    3.5
# Z83826.13  Human DNA sequence from clone RP3-473B4 on chromoso...  44.6    3.5
# Query= scaffold180853-5067
#
# Length=1013
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# KJ460357.1  Panopea globosa microsatellite PglobT65 sequence       206     5e-49
# XM_020073444.1  PREDICTED: Crassostrea gigas tuftelin-interact...  113     8e-21
# XM_011450873.2  PREDICTED: Crassostrea gigas tuftelin-interact...  113     8e-21
# XM_014923098.1  PREDICTED: Octopus bimaculoides tuftelin-inter...  111     3e-20
# XM_014923097.1  PREDICTED: Octopus bimaculoides tuftelin-inter...  111     3e-20
# XM_013208060.1  PREDICTED: Biomphalaria glabrata tuftelin-inte...  100     5e-17
# XM_018076214.1  PREDICTED: Manacus vitellinus tuftelin interac...  77.0    6e-10
# XM_019764003.1  PREDICTED: Branchiostoma belcheri tuftelin-int...  73.4    7e-09
# XM_017814378.1  PREDICTED: Lepidothrix coronata tuftelin inter...  73.4    7e-09
# XM_017814377.1  PREDICTED: Lepidothrix coronata tuftelin inter...  73.4    7e-09
# XM_015877684.1  PREDICTED: Coturnix japonica tuftelin interact...  73.4    7e-09
# XM_007525230.2  PREDICTED: Erinaceus europaeus tuftelin intera...  69.8    9e-08
# XR_001331559.1  PREDICTED: Pseudopodoces humilis tuftelin inte...  69.8    9e-08
# XM_005524332.2  PREDICTED: Pseudopodoces humilis tuftelin inte...  69.8    9e-08
# XM_013556553.1  PREDICTED: Lingula anatina tuftelin-interactin...  69.8    9e-08
# XM_013556552.1  PREDICTED: Lingula anatina tuftelin-interactin...  69.8    9e-08
# XM_013933925.1  PREDICTED: Limulus polyphemus tuftelin-interac...  68.0    3e-07
# NM_001030665.2  Gallus gallus tuftelin interacting protein 11 ...  68.0    3e-07
# AJ720795.1  Gallus gallus mRNA for hypothetical protein, clone...  68.0    3e-07
# XM_013952418.1  PREDICTED: Apteryx australis mantelli tuftelin...  66.2    1e-06
# LK064971.1  Apteryx australis mantelli genome assembly AptMant...  66.2    1e-06
# LM523199.1  Parastrongyloides trichosuri genome assembly P_tri...  64.4    4e-06
# XM_008494766.1  PREDICTED: Calypte anna tuftelin interacting p...  64.4    4e-06
# XM_009084075.1  PREDICTED: Acanthisitta chloris tuftelin inter...  60.8    4e-05
# XM_008634081.2  PREDICTED: Corvus brachyrhynchos tuftelin inte...  59.0    2e-04
# XM_019285056.1  PREDICTED: Corvus cornix cornix tuftelin inter...  55.4    0.002
# XM_015644262.2  PREDICTED: Parus major tuftelin interacting pr...  55.4    0.002
# XM_009092389.2  PREDICTED: Serinus canaria tuftelin interactin...  55.4    0.002
# EU054089.1  Spisula solidissima cnRNA154, complete sequence        55.4    0.002
# XM_006984113.2  PREDICTED: Peromyscus maniculatus bairdii tuft...  53.6    0.007
# XM_016129606.1  PREDICTED: Rousettus aegyptiacus tuftelin inte...  51.8    0.023
# XM_015421277.1  PREDICTED: Gekko japonicus tuftelin interactin...  51.8    0.023
# XM_005421430.2  PREDICTED: Geospiza fortis tuftelin interactin...  51.8    0.023
# XM_005488950.2  PREDICTED: Zonotrichia albicollis tuftelin int...  51.8    0.023
# XM_004715314.2  PREDICTED: Echinops telfairi tuftelin interact...  51.8    0.023
# XM_002197867.2  PREDICTED: Taeniopygia guttata tuftelin intera...  51.8    0.023
# XM_010733691.2  PREDICTED: Larimichthys crocea tuftelin intera...  50.0    0.081
# XM_015810908.1  PREDICTED: Protobothrops mucrosquamatus epider...  50.0    0.081
# XM_014992253.1  PREDICTED: Poecilia mexicana tuftelin interact...  50.0    0.081
# XM_013556515.1  PREDICTED: Lingula anatina espin-like (LOC1061...  50.0    0.081
# LN062864.1  Spirometra erinaceieuropaei genome assembly S_erin...  50.0    0.081
# AC246817.2  Homo sapiens BAC clone CH17-61M15 from chromosome ...  50.0    0.081
# AC104419.3  Homo sapiens chromosome 8, clone RP11-134O21, comp...  50.0    0.081
# AC115485.3  Homo sapiens chromosome 8, clone GS1-57L11, comple...  50.0    0.081
# XM_014809876.1  PREDICTED: Priapulus caudatus tuftelin-interac...  48.2    0.28
# XM_014809875.1  PREDICTED: Priapulus caudatus tuftelin-interac...  48.2    0.28
# XM_014809874.1  PREDICTED: Priapulus caudatus tuftelin-interac...  48.2    0.28
# XM_008648238.1  PREDICTED: Zea mays uncharacterized LOC1036279...  48.2    0.28
# AC208340.4  Zea mays BAC clone CH201-53J11 from chromosome 5, ...  48.2    0.28
# BC077981.1  Xenopus laevis nuclear Y/CCAAT-box binding factor ...  48.2    0.28
# Query= scaffold193328-3840
#
# Length=1039
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# LM471057.1  Parascaris equorum genome assembly P_equorum, scaf...  55.4    0.002
# BK000383.1  TPA: Homo sapiens neuregulin 1 isoform (NRG1) gene...  55.4    0.002
# AF491780.1  Homo sapiens neuregulin 1 (NRG1) gene, partial cds...  55.4    0.002
# AC090816.3  Homo sapiens chromosome 8, clone CTC-386L14, compl...  55.4    0.002
# AC068672.11  Homo sapiens chromosome 8, clone RP11-566H8, comp...  55.4    0.002
# CP017002.1  Plasmodium falciparum 3D7 chromosome 12 sequence       53.6    0.007
# LN999947.1  Plasmodium falciparum 3D7 chromosome 12, complete ...  53.6    0.007
# LM702953.1  Protopolystoma xenopodis genome assembly P_xenopod...  53.6    0.007
# XM_009032504.1  Helobdella robusta hypothetical protein partia...  53.6    0.007
# LK023316.1  Lichtheimia ramosa genome assembly Lramosa_hybrid_...  53.6    0.007
# XM_001350525.1  Plasmodium falciparum 3D7 conserved Plasmodium...  53.6    0.007
# XM_012943601.1  Schistosoma haematobium Homeobox protein SMOX-...  51.8    0.023
# LM071719.1  Schistosoma curassoni genome assembly S_curassoni_...  51.8    0.023
# XM_008029660.1  Setosphaeria turcica Et28A hypothetical protei...  51.8    0.023
# XM_004361791.1  Dictyostelium fasciculatum hypothetical protei...  51.8    0.023
# XM_639805.1  Dictyostelium discoideum AX4 hypothetical protein...  51.8    0.023
# XM_017039626.1  PREDICTED: Cynoglossus semilaevis prostatic sp...  50.0    0.081
# XM_012820051.1  PREDICTED: Clupea harengus nucleophosmin-like ...  50.0    0.081
# LK969850.1  Brugia pahangi genome assembly B_pahangi_Glasgow, ...  50.0    0.081
# LM004381.1  Wuchereria bancrofti genome assembly W_bancrofti_J...  50.0    0.081
# HG670306.1  Triticum aestivum chromosome 3B, genomic scaffold,...  50.0    0.081
# XM_018429424.1  Phycomyces blakesleeanus NRRL 1555(-) hypothet...  48.2    0.28
# XM_018454266.1  PREDICTED: Trachymyrmex zeteki ribosome biogen...  48.2    0.28
# XM_018454265.1  PREDICTED: Trachymyrmex zeteki ribosome biogen...  48.2    0.28
# XM_018454264.1  PREDICTED: Trachymyrmex zeteki ribosome biogen...  48.2    0.28
# CP015659.1  Trypanosoma cruzi cruzi strain Sylvio X10/cl1 chro...  48.2    0.28
# XM_006908581.2  PREDICTED: Pteropus alecto RNA binding motif p...  48.2    0.28
# XM_013936807.1  PREDICTED: Limulus polyphemus replication fact...  48.2    0.28
# XM_013488751.1  Aureobasidium subglaciale EXF-2481 hypothetica...  48.2    0.28
# XM_013402455.1  Exophiala aquamarina CBS 119918 hypothetical p...  48.2    0.28
# XM_011356061.1  PREDICTED: Pteropus vampyrus RNA binding motif...  48.2    0.28
# CP009166.1  Escherichia coli 1303, complete genome                 48.2    0.28
# FO905900.1  Leptosphaeria biglobosa Thlaspii ibcn65_scaffold00...  48.2    0.28
# LM074395.1  Schistosoma curassoni genome assembly S_curassoni_...  48.2    0.28
# LL312165.1  Echinostoma caproni genome assembly E_caproni_Egyp...  48.2    0.28
# LK908484.1  Brugia timori genome assembly B_timori_Indonesia_v...  48.2    0.28
# LM173632.1  Schistosoma mattheei genome assembly S_mattheei_De...  48.2    0.28
# XM_008717097.1  Cyphellophora europaea CBS 101466 hypothetical...  48.2    0.28
# XM_007279324.1  Colletotrichum gloeosporioides Nara gc5 hypoth...  48.2    0.28
# CP002737.1  Methanotorris igneus Kol 5, complete genome            48.2    0.28
# AC243611.5  Rattus norvegicus Y Chr BAC RNAEX-253D23 (Amplicon...  48.2    0.28
# XM_001385839.1  Scheffersomyces stipitis CBS 6054 phosphopanto...  48.2    0.28
# CP000500.1  Scheffersomyces stipitis CBS 6054 chromosome 6, co...  48.2    0.28
# CT573302.9  Zebrafish DNA sequence from clone CH211-94D7 in li...  48.2    0.28
# XM_011419943.2  PREDICTED: Crassostrea gigas pre-rRNA processi...  46.4    0.99
# CP018842.1  Staphylococcus epidermidis strain 14.1.R1, complet...  46.4    0.99
# XM_715497.2  Candida albicans SC5314 Ifh1p (IFH1), partial mRNA    46.4    0.99
# XM_714854.2  Candida albicans SC5314 Apl5p (APL5), partial mRNA    46.4    0.99
# XM_019370152.1  PREDICTED: Nicotiana attenuata acidic leucine-...  46.4    0.99
# XM_018851825.1  Isaria fumosorosea ARSEF 2679 Alcohol acetyltr...  46.4    0.99
# Query= scaffold20564-10594
#
# Length=1135
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# EF999340.1  Elliptio complanata microsatellite Eco_27 sequence     181     2e-41
# KT934029.1  Cristaria plicata phage lysozyme 1 gene, complete cds  163     5e-36
# KJ829664.1  Hyriopsis cumingii clone 193GH SSR marker genomic ...  154     3e-33
# LC122986.1  Cuspidaria cuspidata DNA, SINE:BivaMeta-SINE1, com...  140     6e-29
# LC122981.1  Cuspidaria cuspidata DNA, SINE:BivaMeta-SINE1, com...  140     6e-29
# GQ121398.1  Mercenaria mercenaria microsatellite RUMM041 sequence  140     6e-29
# GQ302643.1  Hyriopsis cumingii clone 10 microsatellite sequence    136     7e-28
# AF108911.1  Mercenaria mercenaria microsatellite Mme225 sequence   132     9e-27
# LC122985.1  Cuspidaria cuspidata DNA, SINE:BivaMeta-SINE1, com...  131     3e-26
# KJ830100.1  Hyriopsis cumingii clone 504GH SSR marker genomic ...  131     3e-26
# GQ121390.1  Mercenaria mercenaria microsatellite RUMM029 sequence  122     2e-23
# GQ340948.1  Solen grandis clone Sg15 microsatellite sequence       122     2e-23
# HF933230.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  120     5e-23
# HF933229.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  118     2e-22
# KJ829673.1  Hyriopsis cumingii clone 328GH SSR marker genomic ...  116     7e-22
# HF933209.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  114     2e-21
# HF933208.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  114     2e-21
# LC122983.1  Cuspidaria cuspidata DNA, SINE:BivaMeta-SINE1, com...  114     2e-21
# KJ830117.1  Hyriopsis cumingii clone 900CH SSR marker genomic ...  114     2e-21
# HF933225.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  113     8e-21
# HF933214.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  113     8e-21
# LC122977.1  Pitar rudis DNA, SINE:BivaMeta-SINE1, complete seq...  113     8e-21
# JF693960.1  Haliotis sieboldii microsatellite A23 sequence         113     8e-21
# GU995501.1  Haliotis discus hannai clone CH1498 microsatellite...  113     8e-21
# AC150407.2  Branchiostoma floridae clone CH302-54J24, complete...  113     8e-21
# HF933227.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  111     3e-20
# HF933224.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  111     3e-20
# HF933221.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  111     3e-20
# HF933215.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  111     3e-20
# HF933212.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  111     3e-20
# LC122988.1  Cuspidaria cuspidata DNA, SINE:BivaMeta-SINE1, com...  111     3e-20
# LC122982.1  Cuspidaria cuspidata DNA, SINE:BivaMeta-SINE1, com...  111     3e-20
# HF933218.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  109     1e-19
# LC122974.1  Pitar rudis DNA, SINE:BivaMeta-SINE1, complete seq...  109     1e-19
# KJ829826.1  Hyriopsis cumingii clone 530GH SSR marker genomic ...  109     1e-19
# KJ829668.1  Hyriopsis cumingii clone 844CH SSR marker genomic ...  109     1e-19
# HF933217.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  107     3e-19
# LC122976.1  Pitar rudis DNA, SINE:BivaMeta-SINE1, complete seq...  107     3e-19
# XM_014825376.1  PREDICTED: Priapulus caudatus LIM domain-conta...  107     3e-19
# KJ829693.1  Hyriopsis cumingii clone 242GF SSR marker genomic ...  107     3e-19
# CT027673.30  L.saxatilis DNA sequence from clone CH317-10N19, ...  107     3e-19
# HF933207.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  105     1e-18
# XM_017441691.1  PREDICTED: Kryptolebias marmoratus paired box ...  105     1e-18
# XM_015953235.1  PREDICTED: Nothobranchius furzeri tubulin poly...  105     1e-18
# AC150392.2  Branchiostoma floridae clone CH302-12P3, complete ...  105     1e-18
# HF933223.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  104     4e-18
# HF933222.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  104     4e-18
# XM_017410822.1  PREDICTED: Kryptolebias marmoratus acyl-coenzy...  104     4e-18
# CT476813.18  L.saxatilis DNA sequence from clone CH317-88D12, ...  104     4e-18
# HF933228.1  TPA: Oryzias latipes strain Hd-rR, complete genome...  102     1e-17
#   Database: Nucleotide collection (nt)
#     Posted date:  Feb 3, 2017  12:59 AM
#   Number of letters in database: 137,855,211,127
#   Number of sequences in database:  41,252,795
#
# Lambda      K        H
#    0.634    0.408    0.912
# Gapped
# Lambda      K        H
#    0.625    0.410    0.780
# Matrix: blastn matrix:2 -3
# Gap Penalties: Existence: 5, Extension: 2
# Number of Sequences: 41252795
# Number of Hits to DB: 141553892
# Number of extensions: 2001877
# Number of successful extensions: 2001877
# Number of sequences better than 10: 531
# Number of HSP's better than 10 without gapping: 0
# Number of HSP's gapped: 2001812
# Number of HSP's successfully gapped: 609
# Length of database: 137855211127
# A: 0
# X1: 22 (20.1 bits)
# X2: 33 (29.8 bits)
# X3: 110 (99.2 bits)
# S1: 28 (26.5 bits)
#
#
#
# ```

# %% [markdown]
# ```
# BLASTX 2.6.1+
# Reference: Stephen F. Altschul, Thomas L. Madden, Alejandro
# A. Schaffer, Jinghui Zhang, Zheng Zhang, Webb Miller, and
# David J. Lipman (1997), "Gapped BLAST and PSI-BLAST: a new
# generation of protein database search programs", Nucleic
# Acids Res. 25:3389-3402.
#
#
# RID: 9M0GA33N014
#
#
# Database: All non-redundant GenBank CDS
# translations+PDB+SwissProt+PIR+PRF excluding environmental samples
# from WGS projects
#            113,671,629 sequences; 41,667,927,126 total letters
# Query= scaffold103946-20422
#
# Length=698
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# XP_019928175.1  PREDICTED: uncharacterized protein K02A2.6-lik...  273     2e-81
# XP_011416566.1  PREDICTED: uncharacterized protein K02A2.6-lik...  273     5e-81
# XP_016306341.1  PREDICTED: hephaestin-like protein 1 [Sinocycl...  265     3e-78
# XP_014667284.1  PREDICTED: uncharacterized protein K02A2.6-lik...  257     4e-77
# XP_018929078.1  PREDICTED: uncharacterized protein K02A2.6-lik...  247     8e-74
# XP_019210590.1  PREDICTED: uncharacterized protein K02A2.6-lik...  246     2e-71
# XP_015757562.1  PREDICTED: uncharacterized protein K02A2.6-lik...  231     6e-69
# XP_015771020.1  PREDICTED: uncharacterized protein K02A2.6-lik...  233     3e-67
# XP_014676064.1  PREDICTED: uncharacterized protein LOC10681603...  230     3e-67
# KXJ24126.1  Retrovirus-related Pol polyprotein from transposon...  223     2e-63
# KXJ28697.1  Retrovirus-related Pol polyprotein from transposon...  221     1e-62
# KKF31357.1  Retrotransposable element Tf2 protein type 1 [Lari...  214     3e-62
# XP_015756987.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     5e-62
# XP_011453065.1  PREDICTED: uncharacterized protein LOC10534625...  201     3e-61
# KXJ06472.1  Retrovirus-related Pol polyprotein from transposon...  211     8e-61
# XP_015761972.1  PREDICTED: uncharacterized protein K02A2.6-lik...  208     1e-60
# XP_019109659.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     2e-60
# KXJ14008.1  Transposon Ty3-I Gag-Pol polyprotein [Exaiptasia p...  214     2e-60
# XP_015765573.1  PREDICTED: uncharacterized protein K02A2.6-lik...  214     3e-60
# XP_015778591.1  PREDICTED: uncharacterized protein K02A2.6-lik...  214     4e-60
# XP_011440770.1  PREDICTED: uncharacterized protein K02A2.6-lik...  214     4e-60
# XP_019749496.1  PREDICTED: uncharacterized protein K02A2.6-lik...  213     1e-59
# XP_014665126.1  PREDICTED: uncharacterized protein K02A2.6-lik...  212     1e-59
# KXJ08876.1  Retrovirus-related Pol polyprotein from transposon...  212     2e-59
# KXJ20749.1  Transposon Ty3-G Gag-Pol polyprotein [Exaiptasia p...  211     4e-59
# XP_019647702.1  PREDICTED: uncharacterized protein K02A2.6-lik...  211     5e-59
# XP_011444530.1  PREDICTED: uncharacterized protein K02A2.6-lik...  199     5e-59
# XP_011415768.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     6e-59
# XP_014676736.1  PREDICTED: uncharacterized protein K02A2.6-lik...  209     7e-59
# XP_019614003.1  PREDICTED: uncharacterized protein K02A2.6-lik...  210     7e-59
# XP_015770983.1  PREDICTED: uncharacterized protein K02A2.6-lik...  209     7e-59
# XP_011454125.1  PREDICTED: uncharacterized protein K02A2.6-lik...  210     7e-59
# XP_019115045.1  PREDICTED: uncharacterized protein K02A2.6-lik...  209     8e-59
# XP_015233581.1  PREDICTED: uncharacterized protein LOC10708686...  206     1e-58
# XP_015798008.1  PREDICTED: uncharacterized protein K02A2.6-lik...  204     2e-58
# XP_013408762.1  PREDICTED: uncharacterized protein K02A2.6-lik...  209     2e-58
# OCA34372.1  hypothetical protein XENTR_v900140432mg, partial [...  208     2e-58
# XP_014187078.1  PREDICTED: uncharacterized protein K02A2.6-lik...  203     2e-58
# KXJ06955.1  Retrovirus-related Pol polyprotein from transposon...  205     3e-58
# XP_018947987.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     5e-58
# XP_015769848.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     5e-58
# XP_019744465.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     7e-58
# XP_011683719.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     1e-57
# XP_011672013.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     1e-57
# XP_008482985.1  PREDICTED: uncharacterized protein K02A2.6-lik...  207     1e-57
# XP_003726516.1  PREDICTED: uncharacterized protein K02A2.6-lik...  203     2e-57
# XP_011661776.1  PREDICTED: uncharacterized protein K02A2.6-lik...  206     2e-57
# ANJ77760.1  polyprotein [Venerupis corrugata]                      190     3e-57
# XP_011422960.1  PREDICTED: uncharacterized protein K02A2.6-lik...  199     3e-57
# KXJ07770.1  Uncharacterized protein K02A2.6 [Exaiptasia pallida]   199     7e-57
# KXJ06809.1  Retrovirus-related Pol polyprotein from transposon...  204     8e-57
# KXJ15515.1  Retrovirus-related Pol polyprotein from transposon...  204     1e-56
# XP_011437820.1  PREDICTED: uncharacterized protein K02A2.6-lik...  204     1e-56
# XP_018402108.1  PREDICTED: uncharacterized protein K02A2.6-lik...  204     1e-56
# XP_019926200.1  PREDICTED: uncharacterized protein LOC10533630...  204     1e-56
# XP_018401702.1  PREDICTED: uncharacterized protein K02A2.6-lik...  203     2e-56
# XP_011447393.1  PREDICTED: uncharacterized protein K02A2.6-lik...  203     2e-56
# XP_019621337.1  PREDICTED: uncharacterized protein K02A2.6-lik...  202     3e-56
# XP_013199002.1  PREDICTED: uncharacterized protein LOC10614191...  189     4e-56
# XP_015833782.1  PREDICTED: uncharacterized protein K02A2.6-lik...  200     4e-56
# XP_015765560.1  PREDICTED: uncharacterized protein K02A2.6-lik...  202     5e-56
# XP_013193584.1  PREDICTED: uncharacterized protein K02A2.6-lik...  202     6e-56
# XP_013198447.1  PREDICTED: uncharacterized protein K02A2.6-lik...  201     8e-56
# XP_011661336.1  PREDICTED: uncharacterized protein K02A2.6-lik...  201     8e-56
# XP_011673489.1  PREDICTED: uncharacterized protein K02A2.6-lik...  201     9e-56
# XP_017298190.1  PREDICTED: uncharacterized protein K02A2.6-lik...  201     1e-55
# KXJ05128.1  Retrovirus-related Pol polyprotein from transposon...  199     1e-55
# XP_013396158.1  PREDICTED: uncharacterized protein K02A2.6-lik...  201     1e-55
# EEZ99875.1  Retrovirus-related Pol polyprotein from transposon...  199     2e-55
# XP_012942558.1  PREDICTED: uncharacterized protein K02A2.6-lik...  198     2e-55
# XP_011677562.1  PREDICTED: uncharacterized protein K02A2.6-lik...  200     2e-55
# ANJ77761.1  polyprotein [Polititapes aureus]                       185     3e-55
# XP_011662146.1  PREDICTED: uncharacterized protein K02A2.6-lik...  200     3e-55
# KXJ09841.1  Uncharacterized protein K02A2.6 [Exaiptasia pallida]   199     4e-55
# XP_011682229.1  PREDICTED: uncharacterized protein K02A2.6-lik...  198     4e-55
# XP_014679393.1  PREDICTED: uncharacterized protein K02A2.6-lik...  189     5e-55
# KXJ23518.1  Transposon Tf2-9 polyprotein [Exaiptasia pallida]      199     5e-55
# XP_019628680.1  PREDICTED: uncharacterized protein K02A2.6-lik...  199     5e-55
# KPJ13895.1  Retrotransposable element Tf2 155 kDa protein type...  197     6e-55
# XP_011663177.1  PREDICTED: uncharacterized protein K02A2.6-lik...  197     7e-55
# KXJ08829.1  Uncharacterized protein K02A2.6 [Exaiptasia pallida]   194     9e-55
# XP_011437834.2  PREDICTED: uncharacterized protein K02A2.6-lik...  198     1e-54
# XP_011678677.1  PREDICTED: uncharacterized protein K02A2.6-lik...  197     1e-54
# KXJ27739.1  Retrovirus-related Pol polyprotein from transposon...  197     2e-54
# XP_019536826.1  PREDICTED: uncharacterized protein K02A2.6-lik...  197     2e-54
# KFM57554.1  Transposon Ty3-I Gag-Pol polyprotein [Stegodyphus ...  197     3e-54
# XP_011664086.1  PREDICTED: uncharacterized protein K02A2.6-lik...  196     3e-54
# XP_015755746.1  PREDICTED: uncharacterized protein K02A2.6-lik...  196     4e-54
# XP_015755743.1  PREDICTED: uncharacterized protein K02A2.6-lik...  195     5e-54
# XP_015750675.1  PREDICTED: uncharacterized protein K02A2.6-lik...  189     5e-54
# KXJ04755.1  Transposon Tf2-8 polyprotein [Exaiptasia pallida]      189     6e-54
# XP_019548916.1  PREDICTED: uncharacterized protein K02A2.6-lik...  193     7e-54
# XP_014665236.1  PREDICTED: uncharacterized protein K02A2.6-lik...  194     1e-53
# XP_018364694.1  PREDICTED: uncharacterized protein K02A2.6-lik...  194     1e-53
# KXJ13038.1  Transposon Tf2-6 polyprotein [Exaiptasia pallida]      194     1e-53
# XP_008484608.1  PREDICTED: uncharacterized protein K02A2.6-lik...  195     1e-53
# XP_008481688.1  PREDICTED: uncharacterized protein K02A2.6-lik...  195     2e-53
# XP_008481687.1  PREDICTED: uncharacterized protein K02A2.6-lik...  195     2e-53
# XP_008484606.1  PREDICTED: uncharacterized protein K02A2.6-lik...  194     2e-53
# XP_008483662.1  PREDICTED: uncharacterized protein K02A2.6-lik...  191     2e-53
# Query= scaffold112102-14447
#
# Length=1474
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# XP_011451658.1  PREDICTED: Krueppel-like factor 6 [Crassostrea...  129     4e-30
# XP_005099170.1  PREDICTED: zinc finger protein 1-like [Aplysia...  115     5e-24
# XP_013085087.1  PREDICTED: Krueppel-like factor 6 [Biomphalari...  111     5e-23
# XP_013406198.1  PREDICTED: Krueppel-like factor 6 [Lingula ana...  79.7    7e-13
# EKC18851.1  Krueppel-like factor 5 [Crassostrea gigas]             58.9    3e-07
# XP_009061300.1  hypothetical protein LOTGIDRAFT_179180 [Lottia...  53.1    2e-05
# XP_014046229.1  PREDICTED: Krueppel-like factor 6 [Salmo salar]    55.8    6e-05
# ELU07190.1  hypothetical protein CAPTEDRAFT_98095 [Capitella t...  52.0    6e-05
# XP_013772769.1  PREDICTED: zinc finger protein 143-like [Limul...  55.8    6e-05
# XP_018010774.1  PREDICTED: Krueppel-like factor 12 [Hyalella a...  56.6    6e-05
# XP_013781707.1  PREDICTED: Krueppel-like factor 7 [Limulus pol...  55.5    7e-05
# CDQ56420.1  unnamed protein product [Oncorhynchus mykiss]          55.5    7e-05
# XP_010881028.1  PREDICTED: Krueppel-like factor 6 [Esox lucius]    54.3    1e-04
# XP_014679621.1  PREDICTED: Krueppel-like factor 6 [Priapulus c...  52.4    2e-04
# XP_013995010.1  PREDICTED: Krueppel-like factor 6 [Salmo salar]    53.9    2e-04
# CDQ62628.1  unnamed protein product [Oncorhynchus mykiss]          53.9    2e-04
# XP_013774978.1  PREDICTED: Krueppel-like factor 6 [Limulus pol...  53.5    3e-04
# KXJ81513.1  hypothetical protein RP20_CCG019381 [Aedes albopic...  52.0    0.001
# XP_308727.4  AGAP007038-PA [Anopheles gambiae str. PEST]           52.4    0.001
# XP_001863112.1  zinc finger protein [Culex quinquefasciatus]       52.0    0.001
# XP_017493385.1  PREDICTED: dendritic arbor reduction protein 1...  52.4    0.001
# XP_004520626.1  PREDICTED: transcription factor Sp4 [Ceratitis...  52.4    0.002
# KDR21067.1  Krueppel-like factor 6 [Zootermopsis nevadensis]       52.0    0.002
# XP_001660650.1  AAEL010126-PA [Aedes aegypti]                      51.6    0.002
# ALC40703.1  luna [Drosophila busckii]                              50.1    0.002
# CRL08495.1  CLUMA_CG021263, isoform A [Clunio marinus]             51.6    0.002
# XP_014407977.1  PREDICTED: Krueppel-like factor 6 isoform X2 [...  50.4    0.003
# XP_001986367.1  GH20565 [Drosophila grimshawi]                     51.6    0.003
# XP_018407831.1  PREDICTED: Krueppel-like factor 6 isoform X1 [...  50.4    0.003
# XP_006874803.1  PREDICTED: Krueppel-like factor 6-like isoform...  50.4    0.003
# XP_016947000.1  PREDICTED: Krueppel-like factor 10 isoform X2 ...  51.2    0.004
# XP_011205494.1  PREDICTED: Krueppel-like factor luna [Bactroce...  51.2    0.004
# XP_011187312.1  PREDICTED: transcription factor Sp4 [Bactrocer...  51.2    0.004
# XP_014087536.1  PREDICTED: Krueppel-like factor 7 [Bactrocera ...  51.2    0.004
# XP_007946303.1  PREDICTED: Krueppel-like factor 6 isoform X2 [...  49.7    0.004
# XP_003967886.1  PREDICTED: Krueppel-like factor 6 [Takifugu ru...  50.1    0.004
# XP_014407976.1  PREDICTED: Krueppel-like factor 6 isoform X1 [...  50.1    0.004
# XP_018804967.1  PREDICTED: Krueppel-like factor luna [Bactroce...  50.8    0.004
# XP_544279.3  PREDICTED: Krueppel-like factor 6 [Canis lupus fa...  50.1    0.004
# XP_016946999.1  PREDICTED: Krueppel-like factor 10 isoform X1 ...  50.8    0.004
# XP_016999205.1  PREDICTED: Krueppel-like factor 6 [Drosophila ...  50.8    0.004
# XP_010960320.1  PREDICTED: Krueppel-like factor 6 [Camelus bac...  50.1    0.005
# XP_004476158.1  PREDICTED: Krueppel-like factor 6 [Dasypus nov...  49.7    0.005
# XP_002026405.1  GL20646 [Drosophila persimilis]                    49.3    0.005
# XP_010588909.1  PREDICTED: Krueppel-like factor 6 [Loxodonta a...  49.7    0.005
# XP_001958687.2  uncharacterized protein Dana_GF12443, isoform ...  50.4    0.005
# JAS36349.1  hypothetical protein g.14290 [Clastoptera arizonana]   50.1    0.006
# XP_007946304.1  PREDICTED: Krueppel-like factor 6 isoform X3 [...  49.7    0.006
# XP_017105930.1  PREDICTED: Krueppel-like factor 7 [Drosophila ...  50.4    0.006
# XP_017835290.1  PREDICTED: dendritic arbor reduction protein 1...  50.4    0.006
# XP_015024270.1  uncharacterized protein Dvir_GJ18175, isoform ...  50.4    0.006
# XP_002059288.2  uncharacterized protein Dvir_GJ18175, isoform ...  50.4    0.006
# XP_002136105.2  uncharacterized protein Dpse_GA28679 [Drosophi...  50.4    0.006
# XP_002139002.2  uncharacterized protein Dpse_GA25126 [Drosophi...  50.4    0.006
# XP_017039072.1  PREDICTED: uncharacterized protein DDB_G027167...  50.4    0.006
# XP_017018523.1  PREDICTED: Krueppel-like factor 7 [Drosophila ...  50.4    0.006
# XP_017149241.1  PREDICTED: Krueppel-like factor 7 [Drosophila ...  50.4    0.006
# XP_017962206.1  PREDICTED: Krueppel-like factor 12 [Drosophila...  50.4    0.006
# XP_017124464.1  PREDICTED: Krueppel-like factor 7 [Drosophila ...  50.4    0.007
# XP_005607019.1  PREDICTED: Krueppel-like factor 6 [Equus cabal...  49.3    0.007
# XP_012864810.1  PREDICTED: Krueppel-like factor 6 [Dipodomys o...  49.3    0.007
# XP_017068856.1  PREDICTED: Krueppel-like factor 7 [Drosophila ...  50.1    0.007
# XP_016026981.1  uncharacterized protein Dsimw501_GD25946 [Dros...  50.1    0.007
# XP_002033321.1  GM20477 [Drosophila sechellia]                     50.1    0.007
# XP_006216002.1  PREDICTED: LOW QUALITY PROTEIN: Krueppel-like ...  49.7    0.007
# XP_002004156.2  LOW QUALITY PROTEIN: uncharacterized protein D...  50.1    0.007
# XP_004390081.1  PREDICTED: Krueppel-like factor 6 isoform X1 [...  49.3    0.007
# XP_017868592.1  PREDICTED: Krueppel-like factor 12 [Drosophila...  50.1    0.008
# XP_002090341.1  uncharacterized protein Dyak_GE13058, isoform ...  50.1    0.008
# NP_995811.1  luna, isoform B [Drosophila melanogaster]             50.1    0.008
# XP_018323921.1  PREDICTED: Krueppel-like factor 7 isoform X3 [...  49.3    0.008
# XP_001976143.1  uncharacterized protein Dere_GG22702 [Drosophi...  50.1    0.008
# XP_016930444.1  PREDICTED: uncharacterized protein DDB_G027167...  50.1    0.008
# XP_018323847.1  PREDICTED: Krueppel-like factor 6 isoform X2 [...  49.3    0.009
# XP_018323772.1  PREDICTED: Krueppel-like factor 6 isoform X1 [...  49.3    0.009
# XP_015833404.1  PREDICTED: Krueppel-like factor 7 isoform X3 [...  49.3    0.009
# XP_005656880.1  PREDICTED: Krueppel-like factor 6 isoform X1 [...  48.9    0.009
# XP_013118858.1  PREDICTED: probable serine/threonine-protein k...  49.7    0.009
# XP_011296126.1  PREDICTED: Krueppel-like factor luna [Musca do...  49.7    0.010
# XP_019867556.1  PREDICTED: Krueppel-like factor 7 [Aethina tum...  48.9    0.010
# XP_017776019.1  PREDICTED: Krueppel-like factor 7 [Nicrophorus...  48.1    0.010
# XP_015811521.1  PREDICTED: Krueppel-like factor 6 [Nothobranch...  48.9    0.011
# XP_008192084.1  PREDICTED: Krueppel-like factor 6 isoform X2 [...  48.9    0.011
# AAI07528.1  KLF6 protein [Bos taurus]                              48.5    0.011
# XP_007054189.1  PREDICTED: Krueppel-like factor 6 isoform X3 [...  48.1    0.011
# XP_017912820.1  PREDICTED: Krueppel-like factor 6 isoform X2 [...  48.5    0.013
# KYB28732.1  hypothetical protein TcasGA2_TC032433 [Tribolium c...  48.9    0.013
# XP_007054187.1  PREDICTED: Krueppel-like factor 6 isoform X1 [...  48.5    0.013
# EHB00826.1  Krueppel-like factor 6 [Heterocephalus glaber]         48.1    0.014
# XP_015833403.1  PREDICTED: Krueppel-like factor 6 isoform X1 [...  48.9    0.014
# XP_016131593.1  PREDICTED: Krueppel-like factor 6 [Sinocycloch...  46.2    0.015
# XP_006058480.1  PREDICTED: Krueppel-like factor 6-like isoform...  48.1    0.015
# XP_005976838.1  PREDICTED: Krueppel-like factor 6 isoform X3 [...  48.1    0.015
# XP_005901871.2  PREDICTED: Krueppel-like factor 6 isoform X3 [...  48.1    0.015
# XP_018571509.1  PREDICTED: Krueppel-like factor luna [Anoploph...  48.5    0.015
# XP_019720098.1  PREDICTED: Krueppel-like factor 6 [Hippocampus...  48.1    0.016
# XP_013779231.1  PREDICTED: Krueppel-like factor 6 [Limulus pol...  48.5    0.016
# XP_016974331.1  PREDICTED: uncharacterized protein DDB_G027167...  48.9    0.016
# XP_004859941.1  PREDICTED: Krueppel-like factor 6 [Heterocepha...  48.1    0.017
# ELR52014.1  Krueppel-like factor 6 [Bos mutus]                     48.1    0.018
# Query= scaffold13704-29380
#
# Length=1035
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# WP_056542554.1  AMP-dependent synthetase [Rhizobium sp. Root1220]  43.5    0.50
# WP_023472055.1  teichuronic acid biosynthesis glycosyltransfer...  40.4    5.2
# Query= scaffold16116-7076
#
# Length=1130
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# CAJ76983.1  transposase [Pachygrapsus marmoratus]                  172     5e-47
# CAJ76986.1  transposase [Pachygrapsus marmoratus]                  172     6e-47
# CAJ76996.1  transposase [Pachygrapsus marmoratus]                  172     6e-47
# CAJ76993.1  transposase [Pachygrapsus marmoratus]                  171     1e-46
# CAJ76994.1  transposase [Pachygrapsus marmoratus]                  171     2e-46
# CAP20047.1  transposase [Portunus granulatus]                      168     3e-45
# CAJ76984.1  transposase [Pachygrapsus marmoratus]                  167     4e-45
# CAP20068.1  transposase [Thalamita poissoni]                       167     5e-45
# CAJ76988.1  transposase [Pachygrapsus marmoratus]                  163     2e-43
# CAP20056.1  transposase [Portunus trituberculatus]                 162     3e-43
# CAP20059.1  transposase [Portunus trituberculatus]                 162     3e-43
# CAP20050.1  transposase [Portunus pelagicus]                       160     3e-42
# CAP20055.1  transposase [Portunus trituberculatus]                 157     2e-41
# ABA55502.1  transposase [Heliothis virescens]                      150     2e-38
# JAS97278.1  hypothetical protein g.11987 [Homalodisca liturata]    145     4e-38
# XP_011873781.1  PREDICTED: histone-lysine N-methyltransferase ...  143     8e-36
# XP_012137479.1  PREDICTED: histone-lysine N-methyltransferase ...  142     8e-36
# XP_018368659.1  PREDICTED: histone-lysine N-methyltransferase ...  142     2e-35
# KMQ82764.1  mariner transposase [Lasius niger]                     142     2e-35
# XP_012147627.1  PREDICTED: putative uncharacterized protein FL...  141     4e-35
# XP_012147626.1  PREDICTED: putative uncharacterized protein FL...  141     5e-35
# APL98290.1  putative DD34D transposase [Bactrocera tryoni]         140     5e-35
# CAP20067.1  transposase [Thalamita poissoni]                       141     5e-35
# XP_012151353.1  PREDICTED: putative uncharacterized protein FL...  140     1e-34
# XP_018317773.1  PREDICTED: putative uncharacterized protein FL...  139     1e-34
# XP_003702583.1  PREDICTED: histone-lysine N-methyltransferase ...  139     2e-34
# APL98286.1  putative DD34D transposase [Bactrocera tryoni]         139     3e-34
# XP_013376018.1  PREDICTED: putative uncharacterized protein FL...  139     3e-34
# JAS57513.1  hypothetical protein g.5018 [Cuerna arida]             134     4e-34
# JAS72555.1  hypothetical protein g.47403 [Homalodisca liturata]    138     5e-34
# XP_014481739.1  PREDICTED: putative uncharacterized protein FL...  137     1e-33
# XP_015436678.1  PREDICTED: histone-lysine N-methyltransferase ...  136     2e-33
# XP_015433579.1  PREDICTED: histone-lysine N-methyltransferase ...  136     3e-33
# KMQ82581.1  mariner mos1 transposase [Lasius niger]                131     3e-33
# XP_012138856.1  PREDICTED: histone-lysine N-methyltransferase ...  135     5e-33
# WP_047149352.1  hypothetical protein [Escherichia coli]            133     5e-33
# APL98288.1  putative DD34D transposase [Bactrocera tryoni]         135     5e-33
# KMQ91440.1  histone-lysine n-methyltransferase setmar-like pro...  134     7e-33
# KMQ86923.1  mariner transposase [Lasius niger]                     134     1e-32
# XP_011878594.1  PREDICTED: histone-lysine N-methyltransferase ...  133     4e-32
# XP_009351334.1  PREDICTED: LOW QUALITY PROTEIN: histone-lysine...  133     4e-32
# KMQ82700.1  histone-lysine n-methyltransferase setmar-like pro...  132     5e-32
# ADB28039.1  transposase [Agrilus planipennis]                      133     5e-32
# APL98291.1  putative DD34D transposase [Bactrocera tryoni]         132     7e-32
# KMQ87583.1  mariner transposase [Lasius niger]                     132     7e-32
# KMQ87532.1  mariner mos1 transposase [Lasius niger]                129     8e-32
# XP_011859854.1  PREDICTED: putative uncharacterized protein FL...  132     1e-31
# NP_001093282.1  mariner transposase [Bombyx mori]                  131     2e-31
# XP_011253084.1  PREDICTED: histone-lysine N-methyltransferase ...  131     2e-31
# APL98289.1  putative DD34D transposase [Bactrocera tryoni]         131     2e-31
# XP_018311644.1  PREDICTED: LOW QUALITY PROTEIN: histone-lysine...  131     2e-31
# XP_017486582.1  PREDICTED: histone-lysine N-methyltransferase ...  131     2e-31
# XP_013199666.1  PREDICTED: histone-lysine N-methyltransferase ...  130     4e-31
# CAP20065.1  transposase [Thalamita poissoni]                       130     4e-31
# XP_011252832.2  PREDICTED: cytochrome P450 4C1-like [Camponotu...  134     5e-31
# APL98292.1  putative DD34D transposase [Bactrocera tryoni]         129     8e-31
# XP_011166492.1  PREDICTED: histone-lysine N-methyltransferase ...  128     3e-30
# JAT93701.1  putative transposase [Amblyomma aureolatum]            127     4e-30
# XP_017486265.1  PREDICTED: histone-lysine N-methyltransferase ...  127     5e-30
# JAS61627.1  hypothetical protein g.37514 [Cuerna arida]            127     6e-30
# XP_011688788.1  PREDICTED: putative uncharacterized protein FL...  127     6e-30
# APL98296.1  truncated putative DD34D transposase [Bactrocera t...  127     7e-30
# XP_014783185.1  PREDICTED: histone-lysine N-methyltransferase ...  127     9e-30
# XP_015432649.1  PREDICTED: histone-lysine N-methyltransferase ...  127     9e-30
# XP_015011487.1  uncharacterized protein Dere_GG27064 [Drosophi...  121     1e-29
# XP_015436017.1  PREDICTED: histone-lysine N-methyltransferase ...  126     1e-29
# XP_018307963.1  PREDICTED: histone-lysine N-methyltransferase ...  125     2e-29
# XP_011250728.1  PREDICTED: histone-lysine N-methyltransferase ...  125     3e-29
# XP_018306891.1  PREDICTED: LOW QUALITY PROTEIN: histone-lysine...  124     4e-29
# APL98287.1  putative DD34D transposase [Bactrocera tryoni]         125     4e-29
# EFA09485.1  Histone-lysine N-methyltransferase SETMAR-like Pro...  124     6e-29
# KMQ82022.1  mariner transposase [Lasius niger]                     120     8e-29
# XP_011268373.1  PREDICTED: histone-lysine N-methyltransferase ...  124     9e-29
# XP_018371330.1  PREDICTED: histone-lysine N-methyltransferase ...  123     2e-28
# JAS51824.1  hypothetical protein g.43369 [Cuerna arida]            121     2e-28
# XP_018049874.1  PREDICTED: histone-lysine N-methyltransferase ...  123     2e-28
# XP_017486515.1  PREDICTED: histone-lysine N-methyltransferase ...  121     2e-28
# XP_018310440.1  PREDICTED: LOW QUALITY PROTEIN: histone-lysine...  122     4e-28
# KMQ85139.1  histone-lysine n-methyltransferase setmar-like pro...  121     5e-28
# KFD56881.1  hypothetical protein M513_02138 [Trichuris suis]       122     5e-28
# XP_015905336.1  PREDICTED: histone-lysine N-methyltransferase ...  120     5e-28
# EFA02770.2  Mariner Mos1 transposase-like Protein [Tribolium c...  118     7e-28
# XP_015014235.1  uncharacterized protein Dere_GG26354 [Drosophi...  115     1e-27
# XP_012143528.1  PREDICTED: putative uncharacterized protein FL...  120     2e-27
# XP_011349879.2  PREDICTED: uncharacterized protein LOC10528655...  120     2e-27
# XP_018349932.1  PREDICTED: histone-lysine N-methyltransferase ...  120     2e-27
# XP_018338842.1  PREDICTED: histone-lysine N-methyltransferase ...  120     2e-27
# JAT04032.1  hypothetical protein g.49984 [Homalodisca liturata]    115     2e-27
# KMQ83645.1  histone-lysine n-methyltransferase setmar-like pro...  119     2e-27
# KFD62063.1  hypothetical protein M514_25782 [Trichuris suis]       120     3e-27
# KFD49184.1  hypothetical protein M513_09906 [Trichuris suis]       120     3e-27
# XP_011165249.1  PREDICTED: histone-lysine N-methyltransferase ...  115     4e-26
# JAS46969.1  hypothetical protein g.37759 [Cuerna arida]            112     7e-26
# KFD64336.1  hypothetical protein M514_09906 [Trichuris suis]       117     7e-26
# XP_012057323.1  PREDICTED: histone-lysine N-methyltransferase ...  114     1e-25
# KFD52867.1  hypothetical protein M513_06177 [Trichuris suis]       115     1e-25
# JAS49634.1  hypothetical protein g.43368 [Cuerna arida]            114     1e-25
# XP_015438009.1  PREDICTED: histone-lysine N-methyltransferase ...  114     2e-25
# XP_018523377.1  PREDICTED: zinc finger protein 280D [Lates cal...  119     2e-25
# XP_015015461.1  uncharacterized protein Dere_GG26334 [Drosophi...  110     2e-25
# Query= scaffold176442-9109
#
# Length=919
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# SCN12114.1  conserved Plasmodium protein, unknown function [Pl...  50.8    0.003
# SBS84322.1  hypothetical protein PMALA_009400 [Plasmodium mala...  46.6    0.061
# XP_001350197.1  conserved Plasmodium membrane protein, unknown...  44.7    0.20
# KNG77485.1  hypothetical protein PFMG_03660 [Plasmodium falcip...  42.0    1.4
# SBT79148.1  conserved Plasmodium protein, unknown function [Pl...  41.6    2.1
# Query= scaffold180853-5067
#
# Length=1013
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# XP_011449175.1  PREDICTED: tuftelin-interacting protein 11 [Cr...  132     2e-30
# EKC18985.1  Tuftelin-interacting protein 11 [Crassostrea gigas]    132     2e-30
# XP_014778583.1  PREDICTED: tuftelin-interacting protein 11-lik...  125     5e-28
# XP_013063514.1  PREDICTED: tuftelin-interacting protein 11-lik...  120     2e-26
# XP_009063581.1  hypothetical protein LOTGIDRAFT_221309 [Lottia...  119     6e-26
# XP_005104240.1  PREDICTED: tuftelin-interacting protein 11-lik...  115     2e-24
# ELU11797.1  hypothetical protein CAPTEDRAFT_169028 [Capitella ...  111     2e-23
# XP_013412006.1  PREDICTED: tuftelin-interacting protein 11-lik...  110     3e-23
# XP_013412007.1  PREDICTED: tuftelin-interacting protein 11-lik...  110     4e-23
# XP_013789379.1  PREDICTED: tuftelin-interacting protein 11-lik...  109     1e-22
# KFM56990.1  Tuftelin-interacting protein 11 [Stegodyphus mimos...  107     5e-22
# XP_002110755.1  hypothetical protein TRIADDRAFT_10976 [Trichop...  107     5e-22
# Q0IIX9.2  RecName: Full=Tuftelin-interacting protein 11; AltNa...  106     9e-22
# NP_001090845.1  tuftelin-interacting protein 11 [Xenopus tropi...  106     9e-22
# OCA36261.1  hypothetical protein XENTR_v90010284mg [Xenopus tr...  106     9e-22
# XP_001641519.1  predicted protein [Nematostella vectensis]         106     9e-22
# XP_007908724.1  PREDICTED: tuftelin-interacting protein 11 iso...  106     1e-21
# XP_007908723.1  PREDICTED: tuftelin-interacting protein 11 iso...  106     1e-21
# XP_019722479.1  PREDICTED: tuftelin-interacting protein 11 [Hi...  106     1e-21
# KFV96103.1  Tuftelin-interacting protein 11 [Eurypyga helias]      101     2e-21
# XP_012559008.1  PREDICTED: tuftelin-interacting protein 11-lik...  105     2e-21
# XP_011477782.1  PREDICTED: LOW QUALITY PROTEIN: tuftelin-inter...  105     3e-21
# KFP49218.1  Tuftelin-interacting protein 11 [Cathartes aura]       102     4e-21
# XP_015919720.1  PREDICTED: tuftelin-interacting protein 11-lik...  104     4e-21
# XP_010156866.1  PREDICTED: tuftelin-interacting protein 11 [Eu...  101     4e-21
# NP_001087642.1  tuftelin-interacting protein 11 [Xenopus laevis]   104     5e-21
# OCT83771.1  hypothetical protein XELAEV_18021910mg [Xenopus la...  104     5e-21
# XP_014847739.1  PREDICTED: tuftelin-interacting protein 11 [Po...  103     9e-21
# XP_015772229.1  PREDICTED: tuftelin-interacting protein 11-lik...  103     9e-21
# XP_008334939.1  PREDICTED: tuftelin-interacting protein 11 [Cy...  103     1e-20
# XP_005874655.1  PREDICTED: tuftelin-interacting protein 11-lik...  103     1e-20
# XP_014326100.1  PREDICTED: tuftelin-interacting protein 11 [Xi...  103     1e-20
# EMP37184.1  Tuftelin-interacting protein 11 [Chelonia mydas]       103     1e-20
# KXJ11983.1  Tuftelin-interacting protein 11 [Exaiptasia pallida]   103     1e-20
# XP_016157171.1  PREDICTED: LOW QUALITY PROTEIN: tuftelin-inter...  103     1e-20
# XP_015828052.1  PREDICTED: tuftelin-interacting protein 11 [No...  103     1e-20
# NP_001091095.1  tuftelin-interacting protein 11 [Takifugu rubr...  103     1e-20
# XP_015228513.1  PREDICTED: tuftelin-interacting protein 11 [Cy...  103     2e-20
# XP_011613947.1  PREDICTED: tuftelin-interacting protein 11 iso...  103     2e-20
# XP_017269109.1  PREDICTED: tuftelin-interacting protein 11 iso...  103     2e-20
# XP_007559301.1  PREDICTED: tuftelin-interacting protein 11 [Po...  103     2e-20
# XP_017269108.1  PREDICTED: tuftelin-interacting protein 11 iso...  103     2e-20
# XP_014883137.1  PREDICTED: tuftelin-interacting protein 11 [Po...  103     2e-20
# XP_002736553.1  PREDICTED: tuftelin-interacting protein 11 [Sa...  102     2e-20
# XP_009965680.1  PREDICTED: tuftelin-interacting protein 11 [Ty...  102     2e-20
# XP_009809419.1  PREDICTED: tuftelin-interacting protein 11 [Ga...  102     2e-20
# KFR00697.1  Tuftelin-interacting protein 11 [Nipponia nippon]      102     2e-20
# XP_009332696.1  PREDICTED: tuftelin-interacting protein 11 [Py...  102     2e-20
# XP_009983332.1  PREDICTED: tuftelin-interacting protein 11 [Ta...  102     2e-20
# KFP95623.1  Tuftelin-interacting protein 11 [Haliaeetus albici...  102     2e-20
# XP_005722307.1  PREDICTED: tuftelin-interacting protein 11 [Pu...  102     2e-20
# XP_008417006.1  PREDICTED: tuftelin-interacting protein 11 [Po...  102     2e-20
# KFW62564.1  Tuftelin-interacting protein 11 [Pygoscelis adeliae]   102     2e-20
# XP_017669867.1  PREDICTED: tuftelin-interacting protein 11 iso...  102     2e-20
# KFQ48373.1  Tuftelin-interacting protein 11 [Pelecanus crispus]    102     2e-20
# XP_009707726.1  PREDICTED: tuftelin-interacting protein 11 [Ca...  102     2e-20
# XP_010306276.1  PREDICTED: tuftelin-interacting protein 11, pa...  102     2e-20
# XP_009281103.1  PREDICTED: tuftelin-interacting protein 11 [Ap...  102     2e-20
# XP_005940191.1  PREDICTED: tuftelin-interacting protein 11 [Ha...  102     2e-20
# XP_004544557.1  PREDICTED: tuftelin-interacting protein 11 [Ma...  102     2e-20
# XP_009571985.1  PREDICTED: tuftelin-interacting protein 11 [Fu...  102     2e-20
# XP_009877288.1  PREDICTED: tuftelin-interacting protein 11 [Ap...  102     2e-20
# KFM09886.1  Tuftelin-interacting protein 11 [Aptenodytes forst...  102     2e-20
# KFP12550.1  Tuftelin-interacting protein 11 [Egretta garzetta]     102     2e-20
# XP_009466848.1  PREDICTED: tuftelin-interacting protein 11 [Ni...  102     2e-20
# XP_009490572.1  PREDICTED: tuftelin-interacting protein 11 [Pe...  102     2e-20
# KGL84782.1  Tuftelin-interacting protein 11 [Tinamus guttatus]     102     2e-20
# KFP35899.1  Tuftelin-interacting protein 11, partial [Chlamydo...  102     2e-20
# XP_009927441.1  PREDICTED: tuftelin-interacting protein 11 [Ha...  102     2e-20
# KGL96598.1  Tuftelin-interacting protein 11 [Charadrius vocife...  102     2e-20
# XP_018524790.1  PREDICTED: tuftelin-interacting protein 11 [La...  102     2e-20
# XP_009511274.1  PREDICTED: tuftelin-interacting protein 11 [Ph...  102     2e-20
# KFV01223.1  Tuftelin-interacting protein 11 [Pterocles guttura...  102     2e-20
# XP_012719018.1  PREDICTED: tuftelin-interacting protein 11 [Fu...  102     2e-20
# XP_008492988.1  PREDICTED: tuftelin-interacting protein 11 [Ca...  102     2e-20
# XP_009090637.1  PREDICTED: tuftelin-interacting protein 11 [Se...  102     2e-20
# XP_005421487.1  PREDICTED: tuftelin-interacting protein 11 [Ge...  102     2e-20
# XP_015686755.1  PREDICTED: tuftelin-interacting protein 11-lik...  98.2    2e-20
# XP_005489007.1  PREDICTED: tuftelin-interacting protein 11 [Zo...  102     2e-20
# KFW83342.1  Tuftelin-interacting protein 11 [Manacus vitellinus]   102     2e-20
# XP_009633041.1  PREDICTED: tuftelin-interacting protein 11 [Eg...  102     2e-20
# XP_013807872.1  PREDICTED: tuftelin-interacting protein 11 [Ap...  102     2e-20
# XP_010294372.1  PREDICTED: tuftelin-interacting protein 11 [Ph...  102     2e-20
# KFQ79462.1  Tuftelin-interacting protein 11 [Phoenicopterus ru...  102     2e-20
# XP_017931703.1  PREDICTED: LOW QUALITY PROTEIN: tuftelin-inter...  102     2e-20
# XP_011588379.1  PREDICTED: tuftelin-interacting protein 11 [Aq...  102     2e-20
# KFO95848.1  Tuftelin-interacting protein 11 [Calypte anna]         102     2e-20
# XP_005230545.1  PREDICTED: tuftelin-interacting protein 11 [Fa...  102     2e-20
# XP_013029209.1  PREDICTED: tuftelin-interacting protein 11 [An...  102     2e-20
# XP_009676417.1  PREDICTED: tuftelin-interacting protein 11 [St...  102     2e-20
# XP_009558777.1  PREDICTED: tuftelin-interacting protein 11 [Cu...  102     2e-20
# XP_014800315.1  PREDICTED: tuftelin-interacting protein 11 iso...  102     2e-20
# XP_019140601.1  PREDICTED: tuftelin-interacting protein 11 [Co...  102     2e-20
# XP_010117527.1  PREDICTED: tuftelin-interacting protein 11, pa...  102     2e-20
# KFV77367.1  Tuftelin-interacting protein 11 [Picoides pubescens]   102     2e-20
# XP_017669866.1  PREDICTED: tuftelin-interacting protein 11 iso...  102     2e-20
# XP_005055056.1  PREDICTED: tuftelin-interacting protein 11 [Fi...  102     2e-20
# XP_010223913.1  PREDICTED: tuftelin-interacting protein 11 [Ti...  102     2e-20
# XP_014800316.1  PREDICTED: tuftelin-interacting protein 11 iso...  102     2e-20
# XP_010580348.1  PREDICTED: tuftelin-interacting protein 11 [Ha...  102     2e-20
# Query= scaffold193328-3840
#
# Length=1039
#
#
#                                                                    Score     E
# Sequences producing significant alignments:                       (Bits)  Value
#
# XP_006741971.1  PREDICTED: EF-hand calcium-binding domain-cont...  41.6    0.60
# XP_012869674.1  PREDICTED: EF-hand calcium-binding domain-cont...  40.8    1.1
# XP_012869667.1  PREDICTED: EF-hand calcium-binding domain-cont...  40.4    1.3
# XP_004376718.1  PREDICTED: EF-hand calcium-binding domain-cont...  40.0    2.1
# XP_004434249.1  PREDICTED: EF-hand calcium-binding domain-cont...  39.7    2.5
# XP_010986795.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.9    3.8
# JAV40676.1  EF-hand calcium-binding domain-containing protein ...  39.3    3.8
# XP_006192907.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.9    4.4
# XP_003787028.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.9    4.4
# XP_006208250.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.9    4.9
# XP_014421615.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.5    5.0
# XP_004682102.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.9    6.7
# XP_010614593.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.5    7.8
# XP_010614592.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.1    9.4
# XP_010614590.1  PREDICTED: EF-hand calcium-binding domain-cont...  38.5    9.6
# XP_012629428.1  PREDICTED: EF-hand calcium-binding domain-cont...  37.7    9.7
# XP_004837134.1  PREDICTED: EF-hand calcium-binding domain-cont...  37.7    9.8
#   Database: All non-redundant GenBank CDS translations+PDB+SwissProt+PIR+PRF
# excluding environmental samples from WGS projects
#     Posted date:  Feb 3, 2017  12:58 AM
#   Number of letters in database: 41,667,927,126
#   Number of sequences in database:  113,671,629
#
# Lambda      K        H
#    0.318    0.134    0.401
# Gapped
# Lambda      K        H
#    0.267   0.0410    0.140
# Matrix: BLOSUM62
# Gap Penalties: Existence: 11, Extension: 1
# Number of Sequences: 113671629
# Number of Hits to DB: 1362980011
# Number of extensions: 560885
# Number of successful extensions: 92839
# Number of sequences better than 10: 209
# Number of HSP's better than 10 without gapping: 0
# Number of HSP's gapped: 92741
# Number of HSP's successfully gapped: 211
# Length of database: 41667927126
# T: 21
# A: 40
# X1: 16 (7.3 bits)
# X2: 38 (14.6 bits)
# X3: 64 (24.7 bits)
# S1: 41 (20.4 bits)
# ka-blk-alpha gapped: 1.9
# ka-blk-alpha ungapped: 0.7916
# ka-blk-alpha_v gapped: 42.6028
# ka-blk-alpha_v ungapped: 4.96466
# ka-blk-sigma gapped: 43.6362
#
#
#
# ```

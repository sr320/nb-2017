# %%
# !bowtie2
# Out:
# No index, query, or output file specified!
# Bowtie 2 version 2.2.4 by Ben Langmead (langmea@cs.jhu.edu, www.cs.jhu.edu/~langmea)
# Usage:
#   bowtie2 [options]* -x <bt2-idx> {-1 <m1> -2 <m2> | -U <r>} [-S <sam>]
#
#   <bt2-idx>  Index filename prefix (minus trailing .X.bt2).
#              NOTE: Bowtie 1 and Bowtie 2 indexes are not compatible.
#   <m1>       Files with #1 mates, paired with files in <m2>.
#              Could be gzip'ed (extension: .gz) or bzip2'ed (extension: .bz2).
#   <m2>       Files with #2 mates, paired with files in <m1>.
#              Could be gzip'ed (extension: .gz) or bzip2'ed (extension: .bz2).
#   <r>        Files with unpaired reads.
#              Could be gzip'ed (extension: .gz) or bzip2'ed (extension: .bz2).
#   <sam>      File for SAM output (default: stdout)
#
#   <m1>, <m2>, <r> can be comma-separated lists (no whitespace) and can be
#   specified many times.  E.g. '-U file1.fq,file2.fq -U file3.fq'.
#
# Options (defaults in parentheses):
#
# ...

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2-build \
/Users/sr320/git-repos/student-fish546-2016/data/Panopea_generosa-Scaff-10k.fa \
/Volumes/Alanine/wd/17-09-15/Panopea_generosa-Scaff-10k.bowtie-index \
&> /Volumes/Alanine/wd/17-09-15/bw-stderr

# %% [markdown]
# # RNA-seq Files

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Volumes/Alanine/wd/17-09-15/Panopea_generosa-Scaff-10k.bowtie-index \
-1 /Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L001_R1_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L002_R1_001.fastq.gz \
-2 /Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L001_R2_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L002_R2_001.fastq.gz \
-p 4 \
-S /Volumes/Alanine/wd/17-09-15/NR005.sam
# Out:
# 78147 reads; of these:
#   78147 (100.00%) were paired; of these:
#     65054 (83.25%) aligned concordantly 0 times
#     11972 (15.32%) aligned concordantly exactly 1 time
#     1121 (1.43%) aligned concordantly >1 times
#     ----
#     65054 pairs aligned concordantly 0 times; of these:
#       3682 (5.66%) aligned discordantly 1 time
#     ----
#     61372 pairs aligned 0 times concordantly or discordantly; of these:
#       122744 mates make up the pairs; of these:
#         117997 (96.13%) aligned 0 times
#         3805 (3.10%) aligned exactly 1 time
#         942 (0.77%) aligned >1 times
# 24.50% overall alignment rate

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Volumes/Alanine/wd/17-09-15/Panopea_generosa-Scaff-10k.bowtie-index \
-1 /Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L001_R1_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L002_R1_001.fastq.gz \
-2 /Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L001_R2_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L002_R2_001.fastq.gz \
-p 4 \
-S /Volumes/Alanine/wd/17-09-15/NR006.sam
# Out:
# 6473873 reads; of these:
#   6473873 (100.00%) were paired; of these:
#     5523074 (85.31%) aligned concordantly 0 times
#     860977 (13.30%) aligned concordantly exactly 1 time
#     89822 (1.39%) aligned concordantly >1 times
#     ----
#     5523074 pairs aligned concordantly 0 times; of these:
#       283935 (5.14%) aligned discordantly 1 time
#     ----
#     5239139 pairs aligned 0 times concordantly or discordantly; of these:
#       10478278 mates make up the pairs; of these:
#         10096854 (96.36%) aligned 0 times
#         299721 (2.86%) aligned exactly 1 time
#         81703 (0.78%) aligned >1 times
# 22.02% overall alignment rate

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Volumes/Alanine/wd/17-09-15/Panopea_generosa-Scaff-10k.bowtie-index \
-1 /Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L001_R1_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L002_R1_001.fastq.gz \
-2 /Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L001_R2_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L002_R2_001.fastq.gz \
-p 4 \
-S /Volumes/Alanine/wd/17-09-15/NR012.sam
# Out:
# 669693 reads; of these:
#   669693 (100.00%) were paired; of these:
#     647021 (96.61%) aligned concordantly 0 times
#     20100 (3.00%) aligned concordantly exactly 1 time
#     2572 (0.38%) aligned concordantly >1 times
#     ----
#     647021 pairs aligned concordantly 0 times; of these:
#       23245 (3.59%) aligned discordantly 1 time
#     ----
#     623776 pairs aligned 0 times concordantly or discordantly; of these:
#       1247552 mates make up the pairs; of these:
#         1105568 (88.62%) aligned 0 times
#         93044 (7.46%) aligned exactly 1 time
#         48940 (3.92%) aligned >1 times
# 17.46% overall alignment rate

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Volumes/Alanine/wd/17-09-15/Panopea_generosa-Scaff-10k.bowtie-index \
-1 /Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L001_R1_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L002_R1_001.fastq.gz \
-2 /Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L001_R2_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L002_R2_001.fastq.gz \
-p 4 \
-S /Volumes/Alanine/wd/17-09-15/NR019.sam
# Out:
# 68487 reads; of these:
#   68487 (100.00%) were paired; of these:
#     67936 (99.20%) aligned concordantly 0 times
#     515 (0.75%) aligned concordantly exactly 1 time
#     36 (0.05%) aligned concordantly >1 times
#     ----
#     67936 pairs aligned concordantly 0 times; of these:
#       538 (0.79%) aligned discordantly 1 time
#     ----
#     67398 pairs aligned 0 times concordantly or discordantly; of these:
#       134796 mates make up the pairs; of these:
#         128942 (95.66%) aligned 0 times
#         4500 (3.34%) aligned exactly 1 time
#         1354 (1.00%) aligned >1 times
# 5.86% overall alignment rate

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Volumes/Alanine/wd/17-09-15/Panopea_generosa-Scaff-10k.bowtie-index \
-1 /Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L001_R1_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L002_R1_001.fastq.gz \
-2 /Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L001_R2_001.fastq.gz,/Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L002_R2_001.fastq.gz \
-p 4 \
-S /Volumes/Alanine/wd/17-09-15/NR021.sam
# Out:
# 7613170 reads; of these:
#   7613170 (100.00%) were paired; of these:
#     6464278 (84.91%) aligned concordantly 0 times
#     1024680 (13.46%) aligned concordantly exactly 1 time
#     124212 (1.63%) aligned concordantly >1 times
#     ----
#     6464278 pairs aligned concordantly 0 times; of these:
#       310801 (4.81%) aligned discordantly 1 time
#     ----
#     6153477 pairs aligned 0 times concordantly or discordantly; of these:
#       12306954 mates make up the pairs; of these:
#         11785504 (95.76%) aligned 0 times
#         392488 (3.19%) aligned exactly 1 time
#         128962 (1.05%) aligned >1 times
# 22.60% overall alignment rate

# %%
cd /Volumes/Alanine/wd/17-09-15/
# Out:
# /Volumes/Alanine/wd/17-09-15

# %%
# !/Applications/bioinfo/FastQC/fastqc -t 6 \
/Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L001_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L002_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L001_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR005_S4_L002_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L001_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L002_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L001_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR006_S3_L002_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L001_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L002_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L001_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR012_S1_L002_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L001_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L002_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L001_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR019_S7_L002_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L001_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L002_R1_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L001_R2_001.fastq.gz \
/Volumes/web/halfshell/working-directory/17-09-07/NR021_S8_L002_R2_001.fastq.gz
# Out:
# Started analysis of NR005_S4_L001_R1_001.fastq.gz
# Started analysis of NR005_S4_L002_R1_001.fastq.gz
# Approx 5% complete for NR005_S4_L001_R1_001.fastq.gz
# Approx 10% complete for NR005_S4_L001_R1_001.fastq.gz
# Started analysis of NR005_S4_L001_R2_001.fastq.gz
# Approx 5% complete for NR005_S4_L002_R1_001.fastq.gz
# Approx 15% complete for NR005_S4_L001_R1_001.fastq.gz
# Approx 20% complete for NR005_S4_L001_R1_001.fastq.gz
# Started analysis of NR005_S4_L002_R2_001.fastq.gz
# Approx 10% complete for NR005_S4_L002_R1_001.fastq.gz
# Approx 25% complete for NR005_S4_L001_R1_001.fastq.gz
# Approx 30% complete for NR005_S4_L001_R1_001.fastq.gz
# Approx 15% complete for NR005_S4_L002_R1_001.fastq.gz
# Approx 35% complete for NR005_S4_L001_R1_001.fastq.gz
# Approx 20% complete for NR005_S4_L002_R1_001.fastq.gz
# Approx 40% complete for NR005_S4_L001_R1_001.fastq.gz
# Approx 25% complete for NR005_S4_L002_R1_001.fastq.gz
# Approx 30% complete for NR005_S4_L002_R1_001.fastq.gz
# ...

# %%
# !multiqc /Volumes/web/halfshell/working-directory/17-09-07/
# Out:
# [INFO   ]         multiqc : This is MultiQC v1.0.dev0
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '/Volumes/web/halfshell/working-directory/17-09-07/'
# [INFO   ]          fastqc : Found 20 reports
# [INFO   ]         multiqc : Report      : multiqc_report.html
# [INFO   ]         multiqc : Data        : multiqc_data
# [INFO   ]         multiqc : MultiQC complete
